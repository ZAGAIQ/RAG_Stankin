# %%
import os
import re
import io
import logging
import requests
import pandas as pd
import fitz
from bs4 import BeautifulSoup
from urllib.parse import urlparse, urljoin
from transformers import AutoTokenizer, AutoModel
import torch
import chromadb
from chromadb import Documents, EmbeddingFunction, Embeddings
from sentence_transformers import SentenceTransformer
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %%
# --- КОНФИГУРАЦИЯ ---
# Настройка логирования
logging.basicConfig(level=logging.INFO,
                    format='%(asctime)s - %(levelname)s - %(message)s')

class STANKIN_RAG_Config:
    START_URL = "https://priem.stankin.ru/"
    BASE_DOMAIN = urlparse(START_URL).netloc
    MAX_CRAWL_DEPTH = 4
    EMBEDDING_MODEL_NAME = "cointegrated/rubert-tiny2"
    CHROMA_DB_PATH = "./stankin_db"
    COLLECTION_NAME = "stankin_collection"
    
    # Параметры чанкинга
    CHUNK_SIZE = 500  # Используем больше, но фильтр по длине все равно сработает
    CHUNK_OVERLAP = 150
    MIN_CHUNK_LEN = 50
    MAX_CHUNK_LEN = 3000
    
    # Регулярные выражения для Анти-Мусор Фильтра (Требование 2.C)
    ANTI_GARBAGE_PATTERNS = [
        re.compile(r'data:image/[a-zA-Z0-9+/=;,-]+'),  # Base64 строки
        re.compile(r'', re.DOTALL),          # HTML комментарии
        re.compile(r'\[Top\.Mail\.Ru\]|Yandex\.Metrika'), # Счетчики/Аналитика
        re.compile(r'^\s*https?://\S+\s*$')              # Чанк - это просто URL
    ]

    PDF_DOCUMENTS = [
        "https://stankin.ru/uploads/files/file_60fa90522da0f.pdf",
        "https://newcloud.stankin.ru/s/sk5ermw7k9Kdxxs/download/2025_%D0%9F%D0%BE%D1%80%D1%8F%D0%B4%D0%BE%D0%BA_%D0%BF%D1%80%D0%BE%D0%B2%D0%B5%D0%B4%D0%B5%D0%BD%D0%B8%D1%8F_%D0%B2%D1%81%D1%82%D1%83%D0%BF%D0%B8%D1%82%D0%B5%D0%BB%D1%8C%D0%BD%D1%8B%D1%85_%D0%B8%D1%81%D0%BF%D1%8B%D1%82%D0%B0%D0%BD%D0%B8%D0%B9_%D0%B2_%D0%B0%D1%81%D0%BF%D0%B8%D1%80%D0%B0%D0%BD%D1%82%D1%83%D1%80%D1%83.pdf",
        "https://newcloud.stankin.ru/s/3X3GL68qHBRZnKN/download/2025_%D0%9F%D0%BE%D1%80%D1%8F%D0%B4%D0%BE%D0%BA_%D0%BF%D1%80%D0%BE%D0%B2%D0%B5%D0%B4%D0%B5%D0%BD%D0%B8%D1%8F_%D0%B2%D1%81%D1%82%D1%83%D0%BF%D0%B8%D1%82%D0%B5%D0%BB%D1%8C%D0%BD%D1%8B%D1%85_%D0%B8%D1%81%D0%BF%D1%8B%D1%82%D0%B0%D0%BD%D0%B8%D0%B9_%D0%B2_%D0%B1%D0%B0%D0%BA,_%D1%81%D0%BF%D0%B5%D1%86.pdf",
        "https://newcloud.stankin.ru/s/sndBbRQqy6wRLCz/download/%D0%9F%D1%80%D0%B0%D0%B2%D0%B8%D0%BB%D0%B0_%D0%BF%D1%80%D0%B8%D0%B5%D0%BC%D0%B0_2025_%D0%90%D0%A1%D0%9F.pdf",
        "https://newcloud.stankin.ru/s/YozjQrwrYcGeDF3/download/%D0%9F%D1%80%D0%B0%D0%B2%D0%B8%D0%BB%D0%B0_%D0%BF%D1%80%D0%B8%D1%91%D0%BC%D0%B0_2025_%D0%91%D0%A1%D0%9C.pdf"
        
        # Добавьте сюда ваши конкретные PDF-файлы
    ]

# %%
# --- МОДУЛЬ 1: ВЕКТОРИЗАЦИЯ (ОБНОВЛЕННЫЙ) ---
class SBERT_EmbeddingFunction(EmbeddingFunction):
    """
    Использует SentenceTransformer для надежной загрузки DeepPavlov модели,
    гарантируя корректный пулинг и нормализацию.
    """
    def __init__(self, model_name: str):
        logging.info(f"Загрузка модели через SentenceTransformer: {model_name}...")
        try:
            # SentenceTransformer автоматически обрабатывает pooling и нормализацию
            self.model = SentenceTransformer(model_name)
            logging.info("SUCCESS: Функция эмбеддинга (SBERT) успешно инициализирована.")
        except Exception as e:
            logging.critical(f"КРИТИЧЕСКАЯ ОШИБКА ЗАГРУЗКИ SBERT: {e}")
            raise

    def __call__(self, texts: Documents) -> Embeddings:
        """Генерирует эмбеддинги."""
        # encode возвращает L2-нормализованные векторы numpy
        embeddings = self.model.encode(texts, convert_to_numpy=True)
        return embeddings.tolist()

# %%
# --- МОДУЛЬ 2: КРАУЛИНГ И ОЧИСТКА ---

def clean_html_content(html_content: str, url: str) -> str:
    """
    Агрессивная очистка HTML: удаление служебных тегов, 
    конвертация таблиц в Markdown.
    """
    soup = BeautifulSoup(html_content, 'lxml')
    
    # 1. Удаление служебных тегов
    REMOVAL_TAGS = ['script', 'style', 'nav', 'footer', 'header', 'form', 'aside', 'iframe', 'noscript']
    for tag in REMOVAL_TAGS:
        for element in soup.find_all(tag):
            element.decompose()
    logging.debug(f"Удалены служебные теги на {url}")

    # 2. Обработка Таблиц (Преобразование в Markdown)
    tables = soup.find_all('table')
    if tables:
        logging.info(f"Обработка {len(tables)} таблиц на странице {url}...")
        for i, table in enumerate(tables):
            try:
                # pandas.read_html может парсить как строку, так и тег
                df = pd.read_html(str(table))[0]
                # Конвертация в Markdown
                markdown_table = "\n\n--- НАЧАЛО ТАБЛИЦЫ ---\n"
                markdown_table += df.to_markdown(index=False)
                markdown_table += "\n--- КОНЕЦ ТАБЛИЦЫ ---\n\n"
                
                # Заменяем тег <table> на его Markdown представление
                table.replace_with(BeautifulSoup(markdown_table, 'html.parser'))
            except Exception as e:
                logging.warning(f"Ошибка парсинга таблицы {i+1} на {url}: {e}")
                table.decompose() # Удаляем проблемную таблицу

    # 3. Финальная очистка текста
    # Получаем чистый текст из оставшегося HTML
    text = soup.get_text(separator=' ', strip=True)
    # Удаляем лишние пробелы и переводы строк
    text = re.sub(r'\s+', ' ', text).strip()
    
    logging.debug(f"HTML-контент страницы {url} очищен. Длина: {len(text)}")
    return text

# %%
def stankin_crawler(start_url: str, max_depth: int) -> dict:
    """
    Рекурсивный краулинг с ограничением по домену и глубине.
    Возвращает словарь {url: content}.
    """
    queue = [(start_url, 0)]
    visited = {start_url}
    page_contents = {}
    base_domain = STANKIN_RAG_Config.BASE_DOMAIN
    
    logging.info(f"Запуск краулинга с {start_url} до глубины {max_depth}...")

    while queue:
        current_url, depth = queue.pop(0)

        if depth > max_depth:
            continue
        
        logging.info(f"-> Парсинг URL: {current_url} (Глубина: {depth})")

        try:
            response = requests.get(current_url, timeout=10)
            # Проверяем успешность и кодировку
            response.raise_for_status()
            response.encoding = response.apparent_encoding 
            
            html_content = response.text
            
            # 1. Очищаем контент
            cleaned_text = clean_html_content(html_content, current_url)
            page_contents[current_url] = cleaned_text
            
            # 2. Поиск новых ссылок
            soup = BeautifulSoup(html_content, 'lxml')
            for link in soup.find_all('a', href=True):
                href = link['href']
                absolute_url = urljoin(current_url, href).split('#')[0] # Убираем якоря
                
                # Проверка на поддомен и посещение
                if urlparse(absolute_url).netloc == base_domain and absolute_url not in visited:
                    visited.add(absolute_url)
                    queue.append((absolute_url, depth + 1))
                    logging.debug(f"DEBUG: Найдена новая ссылка: {absolute_url} (Depth: {depth + 1})")
            
        except requests.exceptions.RequestException as e:
            logging.error(f"Ошибка при загрузке {current_url}: {e}")
        except Exception as e:
            logging.error(f"Непредвиденная ошибка на {current_url}: {e}")

    logging.info(f"SUCCESS: Краулинг завершен. Найдено {len(page_contents)} уникальных страниц.")
    return page_contents

# %%
# --- МОДУЛЬ 3: ЧАНКИНГ И ФИЛЬТРАЦИЯ ---

def create_and_filter_chunks(page_contents: dict) -> list[dict]:
    """
    Разбивает текст на чанки и применяет двойную фильтрацию.
    Возвращает список словарей {text, source}.
    """
    # Инициализация LangChain Text Splitter
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=STANKIN_RAG_Config.CHUNK_SIZE,
        chunk_overlap=STANKIN_RAG_Config.CHUNK_OVERLAP,
        separators=["\n\n", "\n", " ", ""],
        length_function=len
    )
    
    final_chunks = []
    
    logging.info("Применение чанкинга и двойного фильтра ко всему контенту...")

    for url, text in page_contents.items():
        if not text:
            logging.warning(f"Пропущен пустой контент для URL: {url}")
            continue

        # 1. Разбиение на чанки
        chunks = text_splitter.split_text(text)
        logging.info(f"URL: {url} -> Исходный текст разбит на {len(chunks)} чанков.")
        
        for i, chunk in enumerate(chunks):
            # 2. Фильтр 1: По длине (Требование 2.C)
            if not (STANKIN_RAG_Config.MIN_CHUNK_LEN <= len(chunk) <= STANKIN_RAG_Config.MAX_CHUNK_LEN):
                logging.debug(f"CHUNK FILTER (Length): Пропущен чанк #{i} (Длина: {len(chunk)}).")
                continue

            '''
            # 3. Фильтр 2: Анти-Мусор (Требование 2.C)
            is_garbage = False
            for pattern in STANKIN_RAG_Config.ANTI_GARBAGE_PATTERNS:
                if pattern.search(chunk):
                    logging.warning(f"CHUNK FILTER (Garbage): Пропущен чанк #{i} из {url} (Начало: {chunk[:50]}...)")
                    is_garbage = True
                    break
            
            if is_garbage:
                continue
            '''

            # Если чанк прошел все фильтры
            final_chunks.append({
                "text": chunk,
                "source": url
            })

    logging.info(f"SUCCESS: Итоговое количество чанков, готовых к индексированию: {len(final_chunks)}")
    return final_chunks

# %%
# --- МОДУЛЬ 4: ИНДЕКСИРОВАНИЕ ---

def index_chunks_to_chroma(chunks: list[dict], ef: EmbeddingFunction):
    """
    Индексирует очищенные чанки в ChromaDB.
    """
    logging.info(f"Инициализация ChromaDB по пути: {STANKIN_RAG_Config.CHROMA_DB_PATH}")
    client = chromadb.PersistentClient(path=STANKIN_RAG_Config.CHROMA_DB_PATH)
    collection_name = STANKIN_RAG_Config.COLLECTION_NAME
    
    # Требование 2.D: Удаление существующей коллекции
    try:
        client.delete_collection(name=collection_name)
        logging.critical(f"Удалена старая коллекция '{collection_name}' для чистого старта.")
    except:
        logging.info(f"Коллекция '{collection_name}' не найдена или не требует удаления.")

    # Создание новой коллекции с кастомной функцией эмбеддинга
    collection = client.get_or_create_collection(
        name=collection_name, 
        embedding_function=ef,
        metadata={"hnsw:space": "cosine"}
    )
    logging.info(f"Коллекция '{collection_name}' готова к заполнению.")

    # Подготовка данных для пакетного добавления
    documents = [c['text'] for c in chunks]
    metadatas = [{"source": c['source']} for c in chunks]
    # ID's должны быть уникальными (например, URL + индекс чанка)
    ids = [f"{i}-{re.sub(r'[^a-zA-Z0-9]', '_', c['source'])}" for i, c in enumerate(chunks)]

    if not documents:
        logging.warning("Нет документов для индексирования. Пропускаем.")
        return

    # Пакетное добавление
    BATCH_SIZE = 500 
    for i in range(0, len(documents), BATCH_SIZE):
        batch_docs = documents[i:i + BATCH_SIZE]
        batch_metadatas = metadatas[i:i + BATCH_SIZE]
        batch_ids = ids[i:i + BATCH_SIZE]
        
        collection.add(
            documents=batch_docs,
            metadatas=batch_metadatas,
            ids=batch_ids
        )
        logging.info(f"Индексирован пакет: {i} - {min(i + BATCH_SIZE, len(documents))}")
    
    logging.critical(f"SUCCESS: Индексирование завершено. Всего чанков в БД: {collection.count()}")

# %%
# --- МОДУЛЬ 5: ТЕСТИРОВАНИЕ RAG ---

def test_rag_query(query: str, ef: EmbeddingFunction):
    """
    Выполняет тестовый запрос и выводит результаты.
    """
    logging.info("-" * 50)
    logging.info("НАЧАЛО ТЕСТИРОВАНИЯ КАЧЕСТВА RAG")
    logging.info(f"Тестовый запрос: '{query}'")
    
    client = chromadb.PersistentClient(path=STANKIN_RAG_Config.CHROMA_DB_PATH)
    collection_name = STANKIN_RAG_Config.COLLECTION_NAME
    
    try:
        # Получаем коллекцию (с обязательным указанием EF, чтобы запрос кодировался корректно)
        collection = client.get_collection(name=collection_name, embedding_function=ef)
    except Exception as e:
        logging.error(f"Коллекция не найдена. Невозможно выполнить тест. {e}")
        return

    # Выполняем семантический поиск
    results = collection.query(
        query_texts=[query],
        n_results=5, # Требование 2.D
        include=['documents', 'metadatas', 'distances']
    )

    if not results or not results['documents'] or not results['documents'][0]:
        logging.error("Не найдено релевантных документов.")
        return

    logging.critical("\n--- 5 САМЫХ РЕЛЕВАНТНЫХ ЧАНКОВ (RAG-РЕЗУЛЬТАТ) ---\n")
    
    for i in range(5):
        try:
            distance = results['distances'][0][i]
            source = results['metadatas'][0][i]['source']
            content = results['documents'][0][i]
            
            print(f"[{i+1}] Дистанция: {distance:.4f}")
            print(f"    Источник: {source}")
            print(f"    Содержание: {content[:300]}...\n")
            
        except IndexError:
            # Если найдено меньше 5 результатов
            break
            
    logging.info("-" * 50)

# %%
# --- МОДУЛЬ: PDF-ПАРСИНГ ---
def extract_text_from_pdf_url(pdf_url: str) -> str | None:
    """
    Скачивает PDF по URL и извлекает из него текст постранично, 
    используя контекстный менеджер для надежного закрытия.
    """
    logging.info(f"Начало обработки PDF: {pdf_url}")
    
    try:
        # 1. Скачивание содержимого PDF
        response = requests.get(pdf_url, timeout=20) # Увеличим таймаут на всякий случай
        response.raise_for_status() 
        pdf_content = response.content
        
        # 2. Использование fitz.open через BytesIO
        pdf_stream = io.BytesIO(pdf_content)
        
        # 3. Открытие документа и использование try/finally для надежного закрытия
        # Мы используем fitz.open() в try-блоке и закрываем в finally-блоке.
        pdf_document = fitz.open(stream=pdf_stream, filetype="pdf")
        
        full_text = []
        try:
            # 4. Извлечение текста
            for page_num in range(len(pdf_document)):
                page = pdf_document.load_page(page_num)
                text = page.get_text("text")
                full_text.append(f"\n--- Страница {page_num + 1} ---\n{text}")
            
            logging.info(f"SUCCESS: Извлечено текста из PDF ({len(pdf_document)} страниц): {pdf_url}")
            return "\n".join(full_text)
            
        finally:
            # pdf_document.close() гарантированно вызывается здесь,
            # и только после того, как все чтение завершено.
            pdf_document.close()
            
    except requests.exceptions.RequestException as e:
        logging.error(f"Ошибка HTTP при загрузке PDF {pdf_url}: {e}")
        return None
    except Exception as e:
        # Сюда попадет и та самая ошибка 'document closed'
        logging.error(f"Ошибка парсинга PDF {pdf_url}: {e}")
        return None

# --- НОВАЯ ФУНКЦИЯ: ОБРАБОТКА СПИСКА PDF ---
def process_pdf_documents(pdf_urls: list[str]) -> dict[str, str]:
    """
    Парсит список URL-адресов PDF и возвращает словарь: {URL: Текст}.
    """
    pdf_contents = {}
    for url in pdf_urls:
        text = extract_text_from_pdf_url(url)
        if text:
            pdf_contents[url] = text
    return pdf_contents

# %%
def index_data_if_needed(ef: SBERT_EmbeddingFunction) -> bool:
    """
    Выполняет полный пайплайн индексации, если ChromaDB пуста, 
    или если коллекция требует обновления (например, удаляем и создаем заново).
    Возвращает True, если индексация прошла успешно.
    """
    logging.info("ПРОВЕРКА: Проверяем, нужна ли переиндексация...")

    # Здесь можно добавить логику проверки:
    # 1. Если файл базы данных не существует, возвращаем True
    # 2. Если вы хотите всегда пересоздавать базу, просто продолжаем.

    # -------------------------------------------------------------------
    # 1. Сбор и Чанкинг HTML-данных
    logging.info("--- ЭТАП 1: СБОР HTML ДАННЫХ ---")
    html_page_contents = stankin_crawler(
        start_url=STANKIN_RAG_Config.START_URL,
        max_depth=STANKIN_RAG_Config.MAX_CRAWL_DEPTH
    )
    html_chunks = create_and_filter_chunks(html_page_contents)
    logging.info(f"Итого HTML чанков после фильтрации: {len(html_chunks)}")

    # -------------------------------------------------------------------
    # 2. Сбор и Чанкинг PDF-данных
    logging.info("--- ЭТАП 2: СБОР PDF ДАННЫХ ---")
    # Используем Ваше исправленное извлечение PDF
    pdf_page_contents = process_pdf_documents(STANKIN_RAG_Config.PDF_DOCUMENTS)
    pdf_chunks = create_and_filter_chunks(pdf_page_contents)
    logging.info(f"Итого PDF чанков после фильтрации: {len(pdf_chunks)}")

    # -------------------------------------------------------------------
    # 3. Объединение и Индексация
    logging.info("--- ЭТАП 3: ОБЪЕДИНЕНИЕ И ИНДЕКСАЦИЯ ---")
    all_chunks = html_chunks + pdf_chunks 

    if all_chunks:
        # Индексируем, что включает удаление старой коллекции
        index_chunks_to_chroma(all_chunks, ef)
        logging.critical(f"SUCCESS: Общее количество проиндексированных чанков: {len(all_chunks)}")
        return True
    else:
        logging.critical("СИСТЕМА ПУСТА: Нет данных для индексирования.")
        return False

# %%
# logging.critical("СТАРТ RAG-СИСТЕМЫ ПАРСИНГА СТАНКИНА")

# # -------------------------------------------------------------------
# # ШАГ 1: Инициализация Embedding Function
# # -------------------------------------------------------------------
# try:
#     # ИСПОЛЬЗУЕМ КЛАСС SBERT_EmbeddingFunction
#     ef = SBERT_EmbeddingFunction(STANKIN_RAG_Config.EMBEDDING_MODEL_NAME)
# except Exception as e:
#     logging.critical(f"КРИТИЧЕСКАЯ ОШИБКА ИНИЦИАЛИЗАЦИИ МОДЕЛИ: {e}")

# # Инициализация для предотвращения NameError
# html_chunks = []
# pdf_chunks = []

# # -------------------------------------------------------------------
# # ШАГ 2: Сбор, Очистка и Чанкинг HTML-данных
# # -------------------------------------------------------------------
# logging.info("--- ЭТАП 1: СБОР HTML ДАННЫХ ---")
# try:
#     page_contents = stankin_crawler(
#         start_url=STANKIN_RAG_Config.START_URL,
#         max_depth=STANKIN_RAG_Config.MAX_CRAWL_DEPTH
#     )
#     # *** ИСПРАВЛЕНИЕ: Определение html_chunks ***
#     html_chunks = create_and_filter_chunks(page_contents) 
#     logging.info(f"Итого HTML чанков после фильтрации: {len(html_chunks)}")
# except Exception as e:
#     logging.error(f"Ошибка в процессе HTML-краулинга: {e}")

# # -------------------------------------------------------------------
# # ШАГ 3: Сбор, Очистка и Чанкинг PDF-данных
# # -------------------------------------------------------------------
# logging.info("--- ЭТАП 2: СБОР PDF ДАННЫХ ---")
# try:
#     pdf_page_contents = process_pdf_documents(STANKIN_RAG_Config.PDF_DOCUMENTS)
#     pdf_chunks = create_and_filter_chunks(pdf_page_contents)
#     logging.info(f"Итого PDF чанков после фильтрации: {len(pdf_chunks)}")
# except Exception as e:
#     logging.error(f"Ошибка в процессе парсинга PDF: {e}")
    
# # -------------------------------------------------------------------
# # ШАГ 4: Объединение и Индексация в ChromaDB
# # -------------------------------------------------------------------
# logging.info("--- ЭТАП 3: ОБЪЕДИНЕНИЕ И ИНДЕКСАЦИЯ ---")

# # Объединяем оба списка чанков
# all_chunks = html_chunks + pdf_chunks 

# if all_chunks:
#     # Индексируем ВСЕ чанки в одну коллекцию
#     index_chunks_to_chroma(all_chunks, ef)
#     logging.critical(f"SUCCESS: Общее количество проиндексированных чанков: {len(all_chunks)}")
# else:
#     logging.critical("СИСТЕМА ПУСТА: Нет данных для индексирования.")

# # -------------------------------------------------------------------
# # ШАГ 5: Тестирование RAG
# # -------------------------------------------------------------------
# logging.info("--- ЭТАП 4: ТЕСТИРОВАНИЕ RAG-ЗАПРОСОВ ---")
# TEST_QUERY_1 = "Какие документы нужны для подачи заявления в МГТУ СТАНКИН?"
# TEST_QUERY_2 = "Сколько баллов нужно набрать, для того чтобы поступить на направление 09.03.03?"
# TEST_QUERY_3 = "Сколько баллов дают за индивидуальные достижения?"
# TEST_QUERY_4 = "Какие направления подготовки бакалавриата есть в Станкине?"
# TEST_QUERY_5 = "Когда начинаются вступительные испытания в магистратуре?"

# test_rag_query(TEST_QUERY_1, ef)
# test_rag_query(TEST_QUERY_2, ef)
# test_rag_query(TEST_QUERY_3, ef)
# test_rag_query(TEST_QUERY_4, ef)
# test_rag_query(TEST_QUERY_5, ef)

# %%
def main():
    logging.critical("СТАРТ RAG-СИСТЕМЫ: ГИБРИДНЫЙ РЕЖИМ")
    
    # 1. Инициализация модели (нужна и для индексации, и для запросов)
    try:
        ef = SBERT_EmbeddingFunction(STANKIN_RAG_Config.EMBEDDING_MODEL_NAME)
    except Exception as e:
        logging.critical(f"КРИТИЧЕСКАЯ ОШИБКА ИНИЦИАЛИЗАЦИИ МОДЕЛИ: {e}")
        return

# %%
index_data_if_needed(ef)
# Out:
# 2025-12-14 16:57:14,918 - INFO - ПРОВЕРКА: Проверяем, нужна ли переиндексация...
# 2025-12-14 16:57:14,919 - INFO - --- ЭТАП 1: СБОР HTML ДАННЫХ ---
# 2025-12-14 16:57:14,920 - INFO - Запуск краулинга с https://priem.stankin.ru/ до глубины 4...
# 2025-12-14 16:57:14,921 - INFO - -> Парсинг URL: https://priem.stankin.ru/ (Глубина: 0)
# 2025-12-14 16:57:15,539 - INFO - -> Парсинг URL: https://priem.stankin.ru/olympiads/ (Глубина: 1)
# 2025-12-14 16:57:16,148 - INFO - -> Парсинг URL: https://priem.stankin.ru/zadatvoprospk/ (Глубина: 1)
# 2025-12-14 16:57:16,713 - INFO - -> Парсинг URL: https://priem.stankin.ru/meropriyatiya/ (Глубина: 1)
# 2025-12-14 16:57:17,306 - INFO - -> Парсинг URL: https://priem.stankin.ru/rod_sobranie/ (Глубина: 1)
# 2025-12-14 16:57:17,874 - INFO - -> Парсинг URL: https://priem.stankin.ru/podkast_napravleniy/ (Глубина: 1)
# 2025-12-14 16:57:18,459 - INFO - -> Парсинг URL: https://priem.stankin.ru/_dod/ (Глубина: 1)
# 2025-12-14 16:57:19,051 - INFO - -> Парсинг URL: https://priem.stankin.ru/vseros_stankin/ (Глубина: 1)
# 2025-12-14 16:57:19,773 - INFO - -> Парсинг URL: https://priem.stankin.ru/vysokotochnaya_olimpiada/ (Глубина: 1)
# 2025-12-14 16:57:20,823 - INFO - -> Парсинг URL: https://priem.stankin.ru/stud_olymp/ (Глубина: 1)
# 2025-12-14 16:57:21,472 - INFO - -> Парсинг URL: https://priem.stankin.ru/youngschool/ (Глубина: 1)
# 2025-12-14 16:57:22,012 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/submit_documents_bs/ (Глубина: 1)
# 2025-12-14 16:57:22,586 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/training_programs/ (Глубина: 1)
# 2025-12-14 16:57:23,228 - INFO - Обработка 43 таблиц на странице https://priem.stankin.ru/bakalavriatispetsialitet/training_programs/...
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_6928\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_6928\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_6928\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_6928\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_6928\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_6928\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_6928\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_6928\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_6928\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_6928\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_6928\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_6928\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_6928\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_6928\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_6928\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_6928\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_6928\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_6928\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_6928\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_6928\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_6928\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_6928\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_6928\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_6928\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_6928\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_6928\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_6928\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_6928\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_6928\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_6928\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_6928\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_6928\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_6928\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_6928\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_6928\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_6928\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_6928\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_6928\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_6928\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_6928\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_6928\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_6928\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_6928\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# 2025-12-14 16:57:23,575 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/Individual_achievements/ (Глубина: 1)
# 2025-12-14 16:57:24,130 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/exam_schedule/ (Глубина: 1)
# 2025-12-14 16:57:24,786 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/exam_results/ (Глубина: 1)
# 2025-12-14 16:57:25,473 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/min_points/ (Глубина: 1)
# 2025-12-14 16:57:26,035 - INFO - Обработка 3 таблиц на странице https://priem.stankin.ru/bakalavriatispetsialitet/min_points/...
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_6928\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_6928\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_6928\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# 2025-12-14 16:57:26,084 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/programmavvi/ (Глубина: 1)
# 2025-12-14 16:57:26,672 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/formaprovedeniyaekzamenov/ (Глубина: 1)
# 2025-12-14 16:57:27,194 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/daty_priema/ (Глубина: 1)
# 2025-12-14 16:57:27,790 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/terms_of_admission_paid/ (Глубина: 1)
# 2025-12-14 16:57:28,331 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/special_rights/ (Глубина: 1)
# 2025-12-14 16:57:28,908 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/osobkvota/ (Глубина: 1)
# 2025-12-14 16:57:29,488 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/otdkvota/ (Глубина: 1)
# 2025-12-14 16:57:30,113 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/targeted_training/ (Глубина: 1)
# 2025-12-14 16:57:30,637 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/tselevayakvota/ (Глубина: 1)
# 2025-12-14 16:57:31,195 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/podborpredpriyatiyazakazchika/ (Глубина: 1)
# 2025-12-14 16:57:31,742 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/stoimostobucheniya/ (Глубина: 1)
# 2025-12-14 16:57:32,406 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/priemovz/ (Глубина: 1)
# 2025-12-14 16:57:32,924 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/programmaloyalnosti/ (Глубина: 1)
# 2025-12-14 16:57:33,518 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/stipendii_imln/ (Глубина: 1)
# 2025-12-14 16:57:34,091 - INFO - -> Парсинг URL: https://priem.stankin.ru/obshchezhitie/ (Глубина: 1)
# 2025-12-14 16:57:34,643 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/statistika/ (Глубина: 1)
# 2025-12-14 16:57:35,206 - INFO - Обработка 2 таблиц на странице https://priem.stankin.ru/bakalavriatispetsialitet/statistika/...
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_6928\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_6928\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# 2025-12-14 16:57:35,288 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/ranked-lists/ (Глубина: 1)
# 2025-12-14 16:57:35,868 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/ranked-lists-ext/?order=1 (Глубина: 1)
# 2025-12-14 16:57:36,461 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/name-lists/ (Глубина: 1)
# 2025-12-14 16:57:37,069 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/prikazy/ (Глубина: 1)
# 2025-12-14 16:57:37,643 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/ofitsialnyedokumenty/ (Глубина: 1)
# 2025-12-14 16:57:38,121 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/directions/ (Глубина: 1)
# 2025-12-14 16:57:38,639 - INFO - Обработка 1 таблиц на странице https://priem.stankin.ru/bakalavriatispetsialitet/directions/...
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_6928\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# 2025-12-14 16:57:38,671 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/zadatvoprospk/ (Глубина: 1)
# 2025-12-14 16:57:39,194 - INFO - -> Парсинг URL: https://priem.stankin.ru/TOP_IT/ (Глубина: 1)
# 2025-12-14 16:57:39,750 - INFO - -> Парсинг URL: https://priem.stankin.ru/magistratura/podachadokumentov/ (Глубина: 1)
# 2025-12-14 16:57:40,355 - INFO - -> Парсинг URL: https://priem.stankin.ru/magistratura/kcp_mag/ (Глубина: 1)
# 2025-12-14 16:57:40,976 - INFO - Обработка 19 таблиц на странице https://priem.stankin.ru/magistratura/kcp_mag/...
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_6928\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_6928\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_6928\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_6928\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_6928\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_6928\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_6928\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_6928\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_6928\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_6928\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_6928\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_6928\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_6928\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_6928\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_6928\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_6928\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_6928\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_6928\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_6928\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# 2025-12-14 16:57:41,117 - INFO - -> Парсинг URL: https://priem.stankin.ru/magistratura/id/ (Глубина: 1)
# 2025-12-14 16:57:41,703 - INFO - -> Парсинг URL: https://priem.stankin.ru/magistratura/targeted_training/ (Глубина: 1)
# 2025-12-14 16:57:42,240 - INFO - -> Парсинг URL: https://priem.stankin.ru/magistratura/podborpredpriyatiyazakazchika/ (Глубина: 1)
# 2025-12-14 16:57:42,767 - INFO - -> Парсинг URL: https://priem.stankin.ru/magistratura/tselevayakvota/ (Глубина: 1)
# 2025-12-14 16:57:43,345 - INFO - -> Парсинг URL: https://priem.stankin.ru/magistratura/datypriemabyudzhet/ (Глубина: 1)
# 2025-12-14 16:57:44,382 - INFO - -> Парсинг URL: https://priem.stankin.ru/magistratura/datypriemaplatka/ (Глубина: 1)
# 2025-12-14 16:57:44,954 - INFO - -> Парсинг URL: https://priem.stankin.ru/magistratura/cost/ (Глубина: 1)
# 2025-12-14 16:57:45,556 - INFO - -> Парсинг URL: https://priem.stankin.ru/magistratura/raspisanievvi/ (Глубина: 1)
# 2025-12-14 16:57:46,080 - INFO - -> Парсинг URL: https://priem.stankin.ru/magistratura/formaprovedeniyaekzamenov/ (Глубина: 1)
# 2025-12-14 16:57:46,564 - INFO - -> Парсинг URL: https://priem.stankin.ru/magistratura/programmavvi/ (Глубина: 1)
# 2025-12-14 16:57:47,136 - INFO - -> Парсинг URL: https://priem.stankin.ru/magistratura/results_vvi/ (Глубина: 1)
# 2025-12-14 16:57:47,743 - INFO - -> Парсинг URL: https://priem.stankin.ru/magistratura/stipendii/ (Глубина: 1)
# 2025-12-14 16:57:48,245 - INFO - -> Парсинг URL: https://priem.stankin.ru/magistratura/mprogrammaloyalnosti/ (Глубина: 1)
# 2025-12-14 16:57:48,772 - INFO - -> Парсинг URL: https://priem.stankin.ru/magistratura/priemgrazhdansovz/ (Глубина: 1)
# 2025-12-14 16:57:49,292 - INFO - -> Парсинг URL: https://priem.stankin.ru/magistratura/mstat/ (Глубина: 1)
# 2025-12-14 16:57:49,925 - INFO - Обработка 2 таблиц на странице https://priem.stankin.ru/magistratura/mstat/...
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_6928\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_6928\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# 2025-12-14 16:57:49,985 - INFO - -> Парсинг URL: https://priem.stankin.ru/magistratura/ranked-lists/ (Глубина: 1)
# 2025-12-14 16:57:50,577 - INFO - -> Парсинг URL: https://priem.stankin.ru/magistratura/ranked-lists-ext/?order=1 (Глубина: 1)
# 2025-12-14 16:57:51,139 - INFO - -> Парсинг URL: https://priem.stankin.ru/magistratura/name-lists/ (Глубина: 1)
# 2025-12-14 16:57:51,704 - INFO - -> Парсинг URL: https://priem.stankin.ru/magistratura/bsprikazy/ (Глубина: 1)
# 2025-12-14 16:57:52,292 - INFO - -> Парсинг URL: https://priem.stankin.ru/magistratura/ofitsialnyedokumenty/ (Глубина: 1)
# 2025-12-14 16:57:52,846 - INFO - -> Парсинг URL: https://priem.stankin.ru/magistratura/zadatvoprospk/ (Глубина: 1)
# 2025-12-14 16:57:53,397 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/podachadokumentov/ (Глубина: 1)
# 2025-12-14 16:57:53,995 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/programmyobucheniya/ (Глубина: 1)
# 2025-12-14 16:57:54,520 - INFO - Обработка 1 таблиц на странице https://priem.stankin.ru/aspirantura/programmyobucheniya/...
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_6928\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# 2025-12-14 16:57:54,579 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/id/ (Глубина: 1)
# 2025-12-14 16:57:55,187 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/raspisanievvi/ (Глубина: 1)
# 2025-12-14 16:57:55,802 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/formaprovedeniyavvi/ (Глубина: 1)
# 2025-12-14 16:57:56,333 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/programmavvi/ (Глубина: 1)
# 2025-12-14 16:57:56,927 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/results_vvi/ (Глубина: 1)
# 2025-12-14 16:57:57,543 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/srokipriemabyudzhet/ (Глубина: 1)
# 2025-12-14 16:57:58,064 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/srokipriemaplatka/ (Глубина: 1)
# 2025-12-14 16:57:58,585 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/targeted_training/ (Глубина: 1)
# 2025-12-14 16:57:59,139 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/podborpredpriyatiyazakazchika/ (Глубина: 1)
# 2025-12-14 16:57:59,675 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/tselevayakvota/ (Глубина: 1)
# 2025-12-14 16:58:00,274 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/stoimostobucheniya/ (Глубина: 1)
# 2025-12-14 16:58:00,888 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/stipendii/ (Глубина: 1)
# 2025-12-14 16:58:01,488 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/programmaloyalnosti/ (Глубина: 1)
# 2025-12-14 16:58:02,030 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/apriemgrazhdansovz/ (Глубина: 1)
# 2025-12-14 16:58:02,520 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/astat/ (Глубина: 1)
# 2025-12-14 16:58:03,096 - INFO - Обработка 4 таблиц на странице https://priem.stankin.ru/aspirantura/astat/...
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_6928\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_6928\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_6928\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_6928\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# 2025-12-14 16:58:03,182 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/ranked-lists/ (Глубина: 1)
# 2025-12-14 16:58:03,700 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/ranked-lists-ext/?order=1 (Глубина: 1)
# 2025-12-14 16:58:04,249 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/name-lists/ (Глубина: 1)
# 2025-12-14 16:58:04,841 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/bsprikazy/ (Глубина: 1)
# 2025-12-14 16:58:05,410 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/ofitsialnyedokumenty/ (Глубина: 1)
# 2025-12-14 16:58:05,890 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/zadatvoprospk/ (Глубина: 1)
# 2025-12-14 16:58:06,408 - INFO - -> Парсинг URL: https://priem.stankin.ru/priemnayakomissiyastankin_hqev/ (Глубина: 1)
# 2025-12-14 16:58:06,995 - INFO - -> Парсинг URL: https://priem.stankin.ru/perevod_v_Stankin/ (Глубина: 1)
# 2025-12-14 16:58:07,480 - INFO - -> Парсинг URL: https://priem.stankin.ru/youngschool (Глубина: 2)
# 2025-12-14 16:58:08,061 - INFO - -> Парсинг URL: https://priem.stankin.ru/olimpiady/MSO_nachertatlnaya_geometriya/ (Глубина: 2)
# 2025-12-14 16:58:08,513 - INFO - -> Парсинг URL: https://priem.stankin.ru/olimpiady/MSO_programmirovanie/ (Глубина: 2)
# 2025-12-14 16:58:08,941 - INFO - -> Парсинг URL: https://priem.stankin.ru/olimpiady/MSO_computernaya_grafika/ (Глубина: 2)
# 2025-12-14 16:58:09,407 - INFO - -> Парсинг URL: https://priem.stankin.ru/olimpiady/MSO_programnii_dizain/ (Глубина: 2)
# 2025-12-14 16:58:09,860 - INFO - -> Парсинг URL: https://priem.stankin.ru/olimpiady/MSO_teoreticheskya_mehanika/ (Глубина: 2)
# 2025-12-14 16:58:10,350 - INFO - -> Парсинг URL: https://priem.stankin.ru/olimpiady/MSO_matematika/ (Глубина: 2)
# 2025-12-14 16:58:10,830 - INFO - -> Парсинг URL: https://priem.stankin.ru/olimpiady/MSO_informatika/ (Глубина: 2)
# 2025-12-14 16:58:11,308 - INFO - -> Парсинг URL: https://priem.stankin.ru/olimpiady/MSO_fizika/ (Глубина: 2)
# 2025-12-14 16:58:11,808 - INFO - -> Парсинг URL: https://priem.stankin.ru/olimpiady/MSO_inostranniy_yazik/ (Глубина: 2)
# 2025-12-14 16:58:12,285 - INFO - -> Парсинг URL: https://priem.stankin.ru/olimpiady/MSO_teoriya_mehanizmov_i_mashin/ (Глубина: 2)
# 2025-12-14 16:58:12,756 - INFO - -> Парсинг URL: https://priem.stankin.ru/olimpiady/MSO_programmirovanie_obrabotki_na_stankah_s_CHPU_hgbb/ (Глубина: 2)
# 2025-12-14 16:58:13,241 - INFO - -> Парсинг URL: https://priem.stankin.ru/olimpiady/MSO_ekologiya_i_proizvodstvo/ (Глубина: 2)
# 2025-12-14 16:58:13,714 - INFO - -> Парсинг URL: https://priem.stankin.ru/olimpiady/MSO_upravlenie_vysokotekhnologichnym_predpriyatiem/ (Глубина: 2)
# 2025-12-14 16:58:14,149 - INFO - -> Парсинг URL: https://priem.stankin.ru/olimpiady/MSO_tekhnologii_mashinostroeniya/ (Глубина: 2)
# 2025-12-14 16:58:14,635 - INFO - -> Парсинг URL: https://priem.stankin.ru/olimpiady/MSO_proektirovanie_sredstv_proizvodstva/ (Глубина: 2)
# 2025-12-14 16:58:15,100 - INFO - -> Парсинг URL: https://priem.stankin.ru/olimpiady/MSO_soprotivlenie_materialov/ (Глубина: 2)
# 2025-12-14 16:58:15,554 - INFO - -> Парсинг URL: https://priem.stankin.ru/BS_Gosuslugi/ (Глубина: 2)
# 2025-12-14 16:58:16,037 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/01.03.04/ (Глубина: 2)
# 2025-12-14 16:58:16,671 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/09.03.01/ (Глубина: 2)
# 2025-12-14 16:58:17,326 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/09.03.02/ (Глубина: 2)
# 2025-12-14 16:58:17,961 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/09.03.03/ (Глубина: 2)
# 2025-12-14 16:58:18,613 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/09.03.04/ (Глубина: 2)
# 2025-12-14 16:58:19,252 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/12.03.01/ (Глубина: 2)
# 2025-12-14 16:58:19,929 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/15.03.01/ (Глубина: 2)
# 2025-12-14 16:58:20,614 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/15.03.01.01/ (Глубина: 2)
# 2025-12-14 16:58:21,277 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/15.03.02/ (Глубина: 2)
# 2025-12-14 16:58:21,917 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/15.03.04/ (Глубина: 2)
# 2025-12-14 16:58:22,584 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/15.03.05/ (Глубина: 2)
# 2025-12-14 16:58:23,291 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/15.03.06/ (Глубина: 2)
# 2025-12-14 16:58:23,920 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/15.05.01/ (Глубина: 2)
# 2025-12-14 16:58:25,089 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/20.03.01/ (Глубина: 2)
# 2025-12-14 16:58:25,744 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/22.03.01/ (Глубина: 2)
# 2025-12-14 16:58:26,393 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/27.03.01/ (Глубина: 2)
# 2025-12-14 16:58:27,030 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/27.03.02/ (Глубина: 2)
# 2025-12-14 16:58:27,702 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/27.03.04/ (Глубина: 2)
# 2025-12-14 16:58:28,290 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/38.03.01/ (Глубина: 2)
# 2025-12-14 16:58:28,936 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/38.03.02/ (Глубина: 2)
# 2025-12-14 16:58:29,585 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/38.03.03/ (Глубина: 2)
# 2025-12-14 16:58:30,200 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/info_perv_2025/ (Глубина: 2)
# 2025-12-14 16:58:30,749 - INFO - Обработка 4 таблиц на странице https://priem.stankin.ru/bakalavriatispetsialitet/info_perv_2025/...
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_6928\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_6928\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_6928\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_6928\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# 2025-12-14 16:58:30,820 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/info_perv_2025_platnoe/ (Глубина: 2)
# 2025-12-14 16:58:31,346 - INFO - -> Парсинг URL: https://priem.stankin.ru/magistratura/napravleniya/09.04.01/ (Глубина: 2)
# 2025-12-14 16:58:31,964 - INFO - -> Парсинг URL: https://priem.stankin.ru/magistratura/napravleniya/09.04.04/ (Глубина: 2)
# 2025-12-14 16:58:32,597 - INFO - -> Парсинг URL: https://priem.stankin.ru/magistratura/napravleniya/12.04.01/ (Глубина: 2)
# 2025-12-14 16:58:33,235 - INFO - -> Парсинг URL: https://priem.stankin.ru/magistratura/napravleniya/15.04.02/ (Глубина: 2)
# 2025-12-14 16:58:33,858 - INFO - -> Парсинг URL: https://priem.stankin.ru/magistratura/napravleniya/15.04.04/ (Глубина: 2)
# 2025-12-14 16:58:34,495 - INFO - -> Парсинг URL: https://priem.stankin.ru/magistratura/napravleniya/15.04.05/ (Глубина: 2)
# 2025-12-14 16:58:35,125 - INFO - -> Парсинг URL: https://priem.stankin.ru/magistratura/napravleniya/15.04.05.01_siip/ (Глубина: 2)
# 2025-12-14 16:58:35,744 - INFO - -> Парсинг URL: https://priem.stankin.ru/magistratura/napravleniya/15.04.05.02_rpc/ (Глубина: 2)
# 2025-12-14 16:58:36,306 - INFO - -> Парсинг URL: https://priem.stankin.ru/magistratura/napravleniya/15.04.06/ (Глубина: 2)
# 2025-12-14 16:58:36,946 - INFO - -> Парсинг URL: https://priem.stankin.ru/magistratura/napravleniya/20.04.01/ (Глубина: 2)
# 2025-12-14 16:58:37,533 - INFO - -> Парсинг URL: https://priem.stankin.ru/magistratura/napravleniya/27.04.02/ (Глубина: 2)
# 2025-12-14 16:58:38,179 - INFO - -> Парсинг URL: https://priem.stankin.ru/magistratura/napravleniya/27.04.04/ (Глубина: 2)
# 2025-12-14 16:58:38,823 - INFO - -> Парсинг URL: https://priem.stankin.ru/magistratura/napravleniya/38.04.02/ (Глубина: 2)
# 2025-12-14 16:58:39,429 - INFO - -> Парсинг URL: https://priem.stankin.ru/magistratura/napravleniya/38.04.03/ (Глубина: 2)
# 2025-12-14 16:58:40,034 - INFO - -> Парсинг URL: https://priem.stankin.ru/magistratura/napravleniya/38.04.04/ (Глубина: 2)
# 2025-12-14 16:58:40,678 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/napravleniya/1.2.2 (Глубина: 2)
# 2025-12-14 16:58:41,278 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/napravleniya/2.2.11 (Глубина: 2)
# 2025-12-14 16:58:41,899 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/napravleniya/2.3.1 (Глубина: 2)
# 2025-12-14 16:58:42,530 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/napravleniya/2.3.3 (Глубина: 2)
# 2025-12-14 16:58:43,143 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/napravleniya/2.3.7 (Глубина: 2)
# 2025-12-14 16:58:43,747 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/napravleniya/2.5.1 (Глубина: 2)
# 2025-12-14 16:58:44,354 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/napravleniya/2.5.4 (Глубина: 2)
# 2025-12-14 16:58:44,990 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/napravleniya/2.5.5 (Глубина: 2)
# 2025-12-14 16:58:45,595 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/napravleniya/2.5.6 (Глубина: 2)
# 2025-12-14 16:58:46,176 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/napravleniya/2.5.7 (Глубина: 2)
# 2025-12-14 16:58:46,786 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/napravleniya/2.5.22 (Глубина: 2)
# 2025-12-14 16:58:47,340 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/napravleniya/5.2.3 (Глубина: 2)
# 2025-12-14 16:58:47,942 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/napravleniya/5.7.6 (Глубина: 2)
# 2025-12-14 16:58:48,511 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/napravleniya/1.2.2/ (Глубина: 2)
# 2025-12-14 16:58:49,127 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/napravleniya/2.2.11/ (Глубина: 2)
# 2025-12-14 16:58:49,751 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/napravleniya/2.3.1/ (Глубина: 2)
# 2025-12-14 16:58:50,336 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/napravleniya/2.3.3/ (Глубина: 2)
# 2025-12-14 16:58:50,837 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/napravleniya/2.3.7/ (Глубина: 2)
# 2025-12-14 16:58:51,481 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/napravleniya/2.5.1/ (Глубина: 2)
# 2025-12-14 16:58:52,048 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/napravleniya/2.5.4/ (Глубина: 2)
# 2025-12-14 16:58:52,626 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/napravleniya/2.5.5/ (Глубина: 2)
# 2025-12-14 16:58:53,730 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/napravleniya/2.5.6/ (Глубина: 2)
# 2025-12-14 16:58:54,280 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/napravleniya/2.5.7/ (Глубина: 2)
# 2025-12-14 16:58:54,915 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/napravleniya/2.5.22/ (Глубина: 2)
# 2025-12-14 16:58:55,477 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/napravleniya/5.2.3/ (Глубина: 2)
# 2025-12-14 16:58:56,032 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/napravleniya/5.7.6/ (Глубина: 2)
# 2025-12-14 16:58:56,705 - INFO - -> Парсинг URL: https://priem.stankin.ru/priemnayakomissiyastankin_hqev/+7(499) 973-39-66 (Глубина: 2)
# 2025-12-14 16:58:57,078 - ERROR - Ошибка при загрузке https://priem.stankin.ru/priemnayakomissiyastankin_hqev/+7(499) 973-39-66: 404 Client Error: Not Found for url: https://priem.stankin.ru/priemnayakomissiyastankin_hqev/+7(499)%20973-39-66
# 2025-12-14 16:58:57,080 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/profilinapravleniy/MMMQTDA/ (Глубина: 3)
# 2025-12-14 16:58:57,566 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/profilinapravleniy/DSPDTE/ (Глубина: 3)
# 2025-12-14 16:58:58,067 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/profilinapravleniy/DMSISES/ (Глубина: 3)
# 2025-12-14 16:58:58,555 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/profilinapravleniy/MSMPS/ (Глубина: 3)
# 2025-12-14 16:58:59,050 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/profilinapravleniy/DM/ (Глубина: 3)
# 2025-12-14 16:58:59,571 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/profilinapravleniy/SASPD/ (Глубина: 3)
# 2025-12-14 16:59:00,071 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/profilinapravleniy/im_et/ (Глубина: 3)
# 2025-12-14 16:59:00,535 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/profilinapravleniy/MTMbP/ (Глубина: 3)
# 2025-12-14 16:59:01,029 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/profilinapravleniy/MMC/ (Глубина: 3)
# 2025-12-14 16:59:01,521 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/profilinapravleniy/ccm/ (Глубина: 3)
# 2025-12-14 16:59:02,016 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/profilinapravleniy/HMHDH/ (Глубина: 3)
# 2025-12-14 16:59:02,520 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/profilinapravleniy/ATPP/ (Глубина: 3)
# 2025-12-14 16:59:03,008 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/profilinapravleniy/TPMBI/ (Глубина: 3)
# 2025-12-14 16:59:03,459 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/profilinapravleniy/DTSHEMPT/ (Глубина: 3)
# 2025-12-14 16:59:03,976 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/profilinapravleniy/rrs_da/ (Глубина: 3)
# 2025-12-14 16:59:04,451 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/profilinapravleniy/DTCME/ (Глубина: 3)
# 2025-12-14 16:59:04,952 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/profilinapravleniy/IDOS/ (Глубина: 3)
# 2025-12-14 16:59:05,443 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/profilinapravleniy/MCTNM/ (Глубина: 3)
# 2025-12-14 16:59:05,866 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/profilinapravleniy/edp/ (Глубина: 3)
# 2025-12-14 16:59:06,378 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/profilinapravleniy/ohtb/ (Глубина: 3)
# 2025-12-14 16:59:06,884 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/profilinapravleniy/hpm/ (Глубина: 3)
# 2025-12-14 16:59:07,399 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/profilinapravleniy/pmht/ (Глубина: 3)
# 2025-12-14 16:59:07,921 - INFO - -> Парсинг URL: https://priem.stankin.ru/magistratura/napravleniya/profilinapravleniy/pmie_ee_sppm/ (Глубина: 3)
# 2025-12-14 16:59:08,417 - INFO - -> Парсинг URL: https://priem.stankin.ru/magistratura/napravleniya/profilinapravleniy/pmie_ee_ida/ (Глубина: 3)
# 2025-12-14 16:59:08,858 - INFO - -> Парсинг URL: https://priem.stankin.ru/magistratura/napravleniya/profilinapravleniy/pmie_ee_imdesm/ (Глубина: 3)
# 2025-12-14 16:59:09,363 - INFO - -> Парсинг URL: https://priem.stankin.ru/magistratura/napravleniya/profilinapravleniy/pmie_ee_cmcts/ (Глубина: 3)
# ...
# 2025-12-14 16:59:16,387 - INFO - URL: https://priem.stankin.ru/magistratura/napravleniya/38.04.02/ -> Исходный текст разбит на 5 чанков.
# 2025-12-14 16:59:16,388 - INFO - URL: https://priem.stankin.ru/magistratura/napravleniya/38.04.03/ -> Исходный текст разбит на 4 чанков.
# 2025-12-14 16:59:16,390 - INFO - URL: https://priem.stankin.ru/magistratura/napravleniya/38.04.04/ -> Исходный текст разбит на 5 чанков.
# 2025-12-14 16:59:16,391 - INFO - URL: https://priem.stankin.ru/aspirantura/napravleniya/1.2.2 -> Исходный текст разбит на 4 чанков.
# 2025-12-14 16:59:16,393 - INFO - URL: https://priem.stankin.ru/aspirantura/napravleniya/2.2.11 -> Исходный текст разбит на 3 чанков.
# 2025-12-14 16:59:16,395 - INFO - URL: https://priem.stankin.ru/aspirantura/napravleniya/2.3.1 -> Исходный текст разбит на 4 чанков.
# 2025-12-14 16:59:16,397 - INFO - URL: https://priem.stankin.ru/aspirantura/napravleniya/2.3.3 -> Исходный текст разбит на 4 чанков.
# 2025-12-14 16:59:16,399 - INFO - URL: https://priem.stankin.ru/aspirantura/napravleniya/2.3.7 -> Исходный текст разбит на 3 чанков.
# 2025-12-14 16:59:16,400 - INFO - URL: https://priem.stankin.ru/aspirantura/napravleniya/2.5.1 -> Исходный текст разбит на 4 чанков.
# 2025-12-14 16:59:16,402 - INFO - URL: https://priem.stankin.ru/aspirantura/napravleniya/2.5.4 -> Исходный текст разбит на 3 чанков.
# 2025-12-14 16:59:16,403 - INFO - URL: https://priem.stankin.ru/aspirantura/napravleniya/2.5.5 -> Исходный текст разбит на 4 чанков.
# 2025-12-14 16:59:16,405 - INFO - URL: https://priem.stankin.ru/aspirantura/napravleniya/2.5.6 -> Исходный текст разбит на 3 чанков.
# 2025-12-14 16:59:16,407 - INFO - URL: https://priem.stankin.ru/aspirantura/napravleniya/2.5.7 -> Исходный текст разбит на 3 чанков.
# 2025-12-14 16:59:16,408 - INFO - URL: https://priem.stankin.ru/aspirantura/napravleniya/2.5.22 -> Исходный текст разбит на 4 чанков.
# 2025-12-14 16:59:16,410 - INFO - URL: https://priem.stankin.ru/aspirantura/napravleniya/5.2.3 -> Исходный текст разбит на 3 чанков.
# 2025-12-14 16:59:16,411 - INFO - URL: https://priem.stankin.ru/aspirantura/napravleniya/5.7.6 -> Исходный текст разбит на 3 чанков.
# 2025-12-14 16:59:16,413 - INFO - URL: https://priem.stankin.ru/aspirantura/napravleniya/1.2.2/ -> Исходный текст разбит на 4 чанков.
# 2025-12-14 16:59:16,415 - INFO - URL: https://priem.stankin.ru/aspirantura/napravleniya/2.2.11/ -> Исходный текст разбит на 3 чанков.
# 2025-12-14 16:59:16,417 - INFO - URL: https://priem.stankin.ru/aspirantura/napravleniya/2.3.1/ -> Исходный текст разбит на 4 чанков.
# 2025-12-14 16:59:16,418 - INFO - URL: https://priem.stankin.ru/aspirantura/napravleniya/2.3.3/ -> Исходный текст разбит на 4 чанков.
# 2025-12-14 16:59:16,420 - INFO - URL: https://priem.stankin.ru/aspirantura/napravleniya/2.3.7/ -> Исходный текст разбит на 3 чанков.
# 2025-12-14 16:59:16,422 - INFO - URL: https://priem.stankin.ru/aspirantura/napravleniya/2.5.1/ -> Исходный текст разбит на 4 чанков.
# 2025-12-14 16:59:16,423 - INFO - URL: https://priem.stankin.ru/aspirantura/napravleniya/2.5.4/ -> Исходный текст разбит на 3 чанков.
# 2025-12-14 16:59:16,424 - INFO - URL: https://priem.stankin.ru/aspirantura/napravleniya/2.5.5/ -> Исходный текст разбит на 4 чанков.
# 2025-12-14 16:59:16,425 - INFO - URL: https://priem.stankin.ru/aspirantura/napravleniya/2.5.6/ -> Исходный текст разбит на 3 чанков.
# 2025-12-14 16:59:16,428 - INFO - URL: https://priem.stankin.ru/aspirantura/napravleniya/2.5.7/ -> Исходный текст разбит на 3 чанков.
# 2025-12-14 16:59:16,429 - INFO - URL: https://priem.stankin.ru/aspirantura/napravleniya/2.5.22/ -> Исходный текст разбит на 4 чанков.
# 2025-12-14 16:59:16,431 - INFO - URL: https://priem.stankin.ru/aspirantura/napravleniya/5.2.3/ -> Исходный текст разбит на 3 чанков.
# 2025-12-14 16:59:16,433 - INFO - URL: https://priem.stankin.ru/aspirantura/napravleniya/5.7.6/ -> Исходный текст разбит на 3 чанков.
# 2025-12-14 16:59:16,435 - INFO - URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/profilinapravleniy/MMMQTDA/ -> Исходный текст разбит на 10 чанков.
# 2025-12-14 16:59:16,436 - INFO - URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/profilinapravleniy/DSPDTE/ -> Исходный текст разбит на 13 чанков.
# 2025-12-14 16:59:16,438 - INFO - URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/profilinapravleniy/DMSISES/ -> Исходный текст разбит на 14 чанков.
# 2025-12-14 16:59:16,440 - INFO - URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/profilinapravleniy/MSMPS/ -> Исходный текст разбит на 9 чанков.
# 2025-12-14 16:59:16,442 - INFO - URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/profilinapravleniy/DM/ -> Исходный текст разбит на 15 чанков.
# 2025-12-14 16:59:16,444 - INFO - URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/profilinapravleniy/SASPD/ -> Исходный текст разбит на 15 чанков.
# 2025-12-14 16:59:16,446 - INFO - URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/profilinapravleniy/im_et/ -> Исходный текст разбит на 31 чанков.
# 2025-12-14 16:59:16,447 - INFO - URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/profilinapravleniy/MTMbP/ -> Исходный текст разбит на 10 чанков.
# 2025-12-14 16:59:16,448 - INFO - URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/profilinapravleniy/MMC/ -> Исходный текст разбит на 8 чанков.
# 2025-12-14 16:59:16,448 - INFO - URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/profilinapravleniy/ccm/ -> Исходный текст разбит на 11 чанков.
# 2025-12-14 16:59:16,451 - INFO - URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/profilinapravleniy/HMHDH/ -> Исходный текст разбит на 12 чанков.
# 2025-12-14 16:59:16,453 - INFO - URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/profilinapravleniy/ATPP/ -> Исходный текст разбит на 12 чанков.
# 2025-12-14 16:59:16,455 - INFO - URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/profilinapravleniy/TPMBI/ -> Исходный текст разбит на 6 чанков.
# 2025-12-14 16:59:16,457 - INFO - URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/profilinapravleniy/DTSHEMPT/ -> Исходный текст разбит на 14 чанков.
# 2025-12-14 16:59:16,459 - INFO - URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/profilinapravleniy/rrs_da/ -> Исходный текст разбит на 17 чанков.
# 2025-12-14 16:59:16,460 - INFO - URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/profilinapravleniy/DTCME/ -> Исходный текст разбит на 7 чанков.
# 2025-12-14 16:59:16,462 - INFO - URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/profilinapravleniy/IDOS/ -> Исходный текст разбит на 12 чанков.
# 2025-12-14 16:59:16,463 - INFO - URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/profilinapravleniy/MCTNM/ -> Исходный текст разбит на 14 чанков.
# 2025-12-14 16:59:16,466 - INFO - URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/profilinapravleniy/edp/ -> Исходный текст разбит на 14 чанков.
# 2025-12-14 16:59:16,468 - INFO - URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/profilinapravleniy/ohtb/ -> Исходный текст разбит на 13 чанков.
# 2025-12-14 16:59:16,470 - INFO - URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/profilinapravleniy/hpm/ -> Исходный текст разбит на 13 чанков.
# 2025-12-14 16:59:16,471 - INFO - URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/profilinapravleniy/pmht/ -> Исходный текст разбит на 14 чанков.
# 2025-12-14 16:59:16,473 - INFO - URL: https://priem.stankin.ru/magistratura/napravleniya/profilinapravleniy/pmie_ee_sppm/ -> Исходный текст разбит на 13 чанков.
# 2025-12-14 16:59:16,475 - INFO - URL: https://priem.stankin.ru/magistratura/napravleniya/profilinapravleniy/pmie_ee_ida/ -> Исходный текст разбит на 14 чанков.
# 2025-12-14 16:59:16,476 - INFO - URL: https://priem.stankin.ru/magistratura/napravleniya/profilinapravleniy/pmie_ee_imdesm/ -> Исходный текст разбит на 13 чанков.
# 2025-12-14 16:59:16,478 - INFO - URL: https://priem.stankin.ru/magistratura/napravleniya/profilinapravleniy/pmie_ee_cmcts/ -> Исходный текст разбит на 12 чанков.
# 2025-12-14 16:59:16,479 - INFO - URL: https://priem.stankin.ru/magistratura/napravleniya/profilinapravleniy/pmie_ee_aibd/ -> Исходный текст разбит на 13 чанков.
# 2025-12-14 16:59:16,480 - INFO - URL: https://priem.stankin.ru/magistratura/napravleniya/profilinapravleniy/pmie_ee_egcg/ -> Исходный текст разбит на 13 чанков.
# 2025-12-14 16:59:16,482 - INFO - URL: https://priem.stankin.ru/konsultatsiya/ -> Исходный текст разбит на 5 чанков.
# 2025-12-14 16:59:16,483 - INFO - URL: https://priem.stankin.ru/magistratura/napravleniya/profilinapravleniy/TPISPC/ -> Исходный текст разбит на 14 чанков.
# 2025-12-14 16:59:16,486 - INFO - URL: https://priem.stankin.ru/magistratura/napravleniya/profilinapravleniy/MIT/ -> Исходный текст разбит на 30 чанков.
# 2025-12-14 16:59:16,488 - INFO - URL: https://priem.stankin.ru/magistratura/napravleniya/profilinapravleniy/SETP/ -> Исходный текст разбит на 15 чанков.
# 2025-12-14 16:59:16,490 - INFO - URL: https://priem.stankin.ru/magistratura/napravleniya/profilinapravleniy/RPC/ -> Исходный текст разбит на 14 чанков.
# 2025-12-14 16:59:16,492 - INFO - URL: https://priem.stankin.ru/magistratura/napravleniya/profilinapravleniy/pmie_ee/ -> Исходный текст разбит на 12 чанков.
# 2025-12-14 16:59:16,498 - INFO - URL: https://priem.stankin.ru/magistratura/napravleniya/profilinapravleniy/hbm/ -> Исходный текст разбит на 13 чанков.
# 2025-12-14 16:59:16,501 - INFO - URL: https://priem.stankin.ru/magistratura/napravleniya/profilinapravleniy/edp_pbye/ -> Исходный текст разбит на 11 чанков.
# 2025-12-14 16:59:16,503 - INFO - URL: https://priem.stankin.ru/magistratura/napravleniya/profilinapravleniy/prm/ -> Исходный текст разбит на 11 чанков.
# 2025-12-14 16:59:16,506 - INFO - URL: https://priem.stankin.ru/magistratura/napravleniya/profilinapravleniy/pmie/ -> Исходный текст разбит на 10 чанков.
# 2025-12-14 16:59:16,507 - INFO - URL: https://priem.stankin.ru/magistratura/napravleniya/profilinapravleniy/pmie_srppie/ -> Исходный текст разбит на 12 чанков.
# 2025-12-14 16:59:16,508 - INFO - SUCCESS: Итоговое количество чанков, готовых к индексированию: 1609
# 2025-12-14 16:59:16,509 - INFO - Итого HTML чанков после фильтрации: 1609
# 2025-12-14 16:59:16,510 - INFO - --- ЭТАП 2: СБОР PDF ДАННЫХ ---
# 2025-12-14 16:59:16,511 - INFO - Начало обработки PDF: https://stankin.ru/uploads/files/file_60fa90522da0f.pdf
# 2025-12-14 16:59:17,272 - INFO - SUCCESS: Извлечено текста из PDF (5 страниц): https://stankin.ru/uploads/files/file_60fa90522da0f.pdf
# 2025-12-14 16:59:17,274 - INFO - Начало обработки PDF: https://newcloud.stankin.ru/s/sk5ermw7k9Kdxxs/download/2025_%D0%9F%D0%BE%D1%80%D1%8F%D0%B4%D0%BE%D0%BA_%D0%BF%D1%80%D0%BE%D0%B2%D0%B5%D0%B4%D0%B5%D0%BD%D0%B8%D1%8F_%D0%B2%D1%81%D1%82%D1%83%D0%BF%D0%B8%D1%82%D0%B5%D0%BB%D1%8C%D0%BD%D1%8B%D1%85_%D0%B8%D1%81%D0%BF%D1%8B%D1%82%D0%B0%D0%BD%D0%B8%D0%B9_%D0%B2_%D0%B0%D1%81%D0%BF%D0%B8%D1%80%D0%B0%D0%BD%D1%82%D1%83%D1%80%D1%83.pdf
# 2025-12-14 16:59:17,652 - INFO - SUCCESS: Извлечено текста из PDF (8 страниц): https://newcloud.stankin.ru/s/sk5ermw7k9Kdxxs/download/2025_%D0%9F%D0%BE%D1%80%D1%8F%D0%B4%D0%BE%D0%BA_%D0%BF%D1%80%D0%BE%D0%B2%D0%B5%D0%B4%D0%B5%D0%BD%D0%B8%D1%8F_%D0%B2%D1%81%D1%82%D1%83%D0%BF%D0%B8%D1%82%D0%B5%D0%BB%D1%8C%D0%BD%D1%8B%D1%85_%D0%B8%D1%81%D0%BF%D1%8B%D1%82%D0%B0%D0%BD%D0%B8%D0%B9_%D0%B2_%D0%B0%D1%81%D0%BF%D0%B8%D1%80%D0%B0%D0%BD%D1%82%D1%83%D1%80%D1%83.pdf
# 2025-12-14 16:59:17,656 - INFO - Начало обработки PDF: https://newcloud.stankin.ru/s/3X3GL68qHBRZnKN/download/2025_%D0%9F%D0%BE%D1%80%D1%8F%D0%B4%D0%BE%D0%BA_%D0%BF%D1%80%D0%BE%D0%B2%D0%B5%D0%B4%D0%B5%D0%BD%D0%B8%D1%8F_%D0%B2%D1%81%D1%82%D1%83%D0%BF%D0%B8%D1%82%D0%B5%D0%BB%D1%8C%D0%BD%D1%8B%D1%85_%D0%B8%D1%81%D0%BF%D1%8B%D1%82%D0%B0%D0%BD%D0%B8%D0%B9_%D0%B2_%D0%B1%D0%B0%D0%BA,_%D1%81%D0%BF%D0%B5%D1%86.pdf
# 2025-12-14 16:59:18,046 - INFO - SUCCESS: Извлечено текста из PDF (10 страниц): https://newcloud.stankin.ru/s/3X3GL68qHBRZnKN/download/2025_%D0%9F%D0%BE%D1%80%D1%8F%D0%B4%D0%BE%D0%BA_%D0%BF%D1%80%D0%BE%D0%B2%D0%B5%D0%B4%D0%B5%D0%BD%D0%B8%D1%8F_%D0%B2%D1%81%D1%82%D1%83%D0%BF%D0%B8%D1%82%D0%B5%D0%BB%D1%8C%D0%BD%D1%8B%D1%85_%D0%B8%D1%81%D0%BF%D1%8B%D1%82%D0%B0%D0%BD%D0%B8%D0%B9_%D0%B2_%D0%B1%D0%B0%D0%BA,_%D1%81%D0%BF%D0%B5%D1%86.pdf
# 2025-12-14 16:59:18,048 - INFO - Начало обработки PDF: https://newcloud.stankin.ru/s/sndBbRQqy6wRLCz/download/%D0%9F%D1%80%D0%B0%D0%B2%D0%B8%D0%BB%D0%B0_%D0%BF%D1%80%D0%B8%D0%B5%D0%BC%D0%B0_2025_%D0%90%D0%A1%D0%9F.pdf
# 2025-12-14 16:59:18,587 - INFO - SUCCESS: Извлечено текста из PDF (23 страниц): https://newcloud.stankin.ru/s/sndBbRQqy6wRLCz/download/%D0%9F%D1%80%D0%B0%D0%B2%D0%B8%D0%BB%D0%B0_%D0%BF%D1%80%D0%B8%D0%B5%D0%BC%D0%B0_2025_%D0%90%D0%A1%D0%9F.pdf
# 2025-12-14 16:59:18,589 - INFO - Начало обработки PDF: https://newcloud.stankin.ru/s/YozjQrwrYcGeDF3/download/%D0%9F%D1%80%D0%B0%D0%B2%D0%B8%D0%BB%D0%B0_%D0%BF%D1%80%D0%B8%D1%91%D0%BC%D0%B0_2025_%D0%91%D0%A1%D0%9C.pdf
# 2025-12-14 16:59:19,173 - INFO - SUCCESS: Извлечено текста из PDF (69 страниц): https://newcloud.stankin.ru/s/YozjQrwrYcGeDF3/download/%D0%9F%D1%80%D0%B0%D0%B2%D0%B8%D0%BB%D0%B0_%D0%BF%D1%80%D0%B8%D1%91%D0%BC%D0%B0_2025_%D0%91%D0%A1%D0%9C.pdf
# 2025-12-14 16:59:19,175 - INFO - Применение чанкинга и двойного фильтра ко всему контенту...
# 2025-12-14 16:59:19,176 - INFO - URL: https://stankin.ru/uploads/files/file_60fa90522da0f.pdf -> Исходный текст разбит на 1 чанков.
# 2025-12-14 16:59:19,177 - INFO - URL: https://newcloud.stankin.ru/s/sk5ermw7k9Kdxxs/download/2025_%D0%9F%D0%BE%D1%80%D1%8F%D0%B4%D0%BE%D0%BA_%D0%BF%D1%80%D0%BE%D0%B2%D0%B5%D0%B4%D0%B5%D0%BD%D0%B8%D1%8F_%D0%B2%D1%81%D1%82%D1%83%D0%BF%D0%B8%D1%82%D0%B5%D0%BB%D1%8C%D0%BD%D1%8B%D1%85_%D0%B8%D1%81%D0%BF%D1%8B%D1%82%D0%B0%D0%BD%D0%B8%D0%B9_%D0%B2_%D0%B0%D1%81%D0%BF%D0%B8%D1%80%D0%B0%D0%BD%D1%82%D1%83%D1%80%D1%83.pdf -> Исходный текст разбит на 46 чанков.
# 2025-12-14 16:59:19,180 - INFO - URL: https://newcloud.stankin.ru/s/3X3GL68qHBRZnKN/download/2025_%D0%9F%D0%BE%D1%80%D1%8F%D0%B4%D0%BE%D0%BA_%D0%BF%D1%80%D0%BE%D0%B2%D0%B5%D0%B4%D0%B5%D0%BD%D0%B8%D1%8F_%D0%B2%D1%81%D1%82%D1%83%D0%BF%D0%B8%D1%82%D0%B5%D0%BB%D1%8C%D0%BD%D1%8B%D1%85_%D0%B8%D1%81%D0%BF%D1%8B%D1%82%D0%B0%D0%BD%D0%B8%D0%B9_%D0%B2_%D0%B1%D0%B0%D0%BA,_%D1%81%D0%BF%D0%B5%D1%86.pdf -> Исходный текст разбит на 66 чанков.
# 2025-12-14 16:59:19,184 - INFO - URL: https://newcloud.stankin.ru/s/sndBbRQqy6wRLCz/download/%D0%9F%D1%80%D0%B0%D0%B2%D0%B8%D0%BB%D0%B0_%D0%BF%D1%80%D0%B8%D0%B5%D0%BC%D0%B0_2025_%D0%90%D0%A1%D0%9F.pdf -> Исходный текст разбит на 199 чанков.
# 2025-12-14 16:59:19,189 - INFO - URL: https://newcloud.stankin.ru/s/YozjQrwrYcGeDF3/download/%D0%9F%D1%80%D0%B0%D0%B2%D0%B8%D0%BB%D0%B0_%D0%BF%D1%80%D0%B8%D1%91%D0%BC%D0%B0_2025_%D0%91%D0%A1%D0%9C.pdf -> Исходный текст разбит на 453 чанков.
# 2025-12-14 16:59:19,191 - INFO - SUCCESS: Итоговое количество чанков, готовых к индексированию: 761
# 2025-12-14 16:59:19,192 - INFO - Итого PDF чанков после фильтрации: 761
# 2025-12-14 16:59:19,193 - INFO - --- ЭТАП 3: ОБЪЕДИНЕНИЕ И ИНДЕКСАЦИЯ ---
# 2025-12-14 16:59:19,194 - INFO - Инициализация ChromaDB по пути: ./stankin_db
# 2025-12-14 16:59:19,507 - CRITICAL - Удалена старая коллекция 'stankin_collection' для чистого старта.
# 2025-12-14 16:59:19,532 - INFO - Коллекция 'stankin_collection' готова к заполнению.
# Batches:   0%|          | 0/16 [00:00<?, ?it/s]
# 2025-12-14 16:59:28,699 - INFO - Индексирован пакет: 0 - 500
# Batches:   0%|          | 0/16 [00:00<?, ?it/s]
# 2025-12-14 16:59:35,387 - INFO - Индексирован пакет: 500 - 1000
# Batches:   0%|          | 0/16 [00:00<?, ?it/s]
# 2025-12-14 16:59:39,282 - INFO - Индексирован пакет: 1000 - 1500
# Batches:   0%|          | 0/16 [00:00<?, ?it/s]
# 2025-12-14 16:59:44,870 - INFO - Индексирован пакет: 1500 - 2000
# Batches:   0%|          | 0/12 [00:00<?, ?it/s]
# 2025-12-14 16:59:46,963 - INFO - Индексирован пакет: 2000 - 2370
# 2025-12-14 16:59:46,987 - CRITICAL - SUCCESS: Индексирование завершено. Всего чанков в БД: 2370
# 2025-12-14 16:59:46,989 - CRITICAL - SUCCESS: Общее количество проиндексированных чанков: 2370
# True

# %%
TEST_QUERY_1 = "Какие документы нужны для подачи заявления в МГТУ СТАНКИН?"
TEST_QUERY_2 = "Сколько баллов нужно набрать, для того чтобы поступить на направление 09.03.03?"
TEST_QUERY_3 = "Сколько баллов дают за индивидуальные достижения?"
TEST_QUERY_4 = "Какие направления подготовки бакалавриата есть в Станкине?"
TEST_QUERY_5 = "Когда начинаются вступительные испытания в магистратуре?"

test_rag_query(TEST_QUERY_1, ef)
test_rag_query(TEST_QUERY_2, ef)
test_rag_query(TEST_QUERY_3, ef)
test_rag_query(TEST_QUERY_4, ef)
test_rag_query(TEST_QUERY_5, ef)
# Out:
# 2025-12-14 16:59:57,507 - INFO - --------------------------------------------------
# 2025-12-14 16:59:57,508 - INFO - НАЧАЛО ТЕСТИРОВАНИЯ КАЧЕСТВА RAG
# 2025-12-14 16:59:57,509 - INFO - Тестовый запрос: 'Какие документы нужны для подачи заявления в МГТУ СТАНКИН?'
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# 2025-12-14 16:59:57,580 - CRITICAL -
# --- 5 САМЫХ РЕЛЕВАНТНЫХ ЧАНКОВ (RAG-РЕЗУЛЬТАТ) ---
#
# 2025-12-14 16:59:57,582 - INFO - --------------------------------------------------
# 2025-12-14 16:59:57,582 - INFO - --------------------------------------------------
# 2025-12-14 16:59:57,583 - INFO - НАЧАЛО ТЕСТИРОВАНИЯ КАЧЕСТВА RAG
# 2025-12-14 16:59:57,583 - INFO - Тестовый запрос: 'Сколько баллов нужно набрать, для того чтобы поступить на направление 09.03.03?'
# [1] Дистанция: 0.2862
#     Источник: https://newcloud.stankin.ru/s/sndBbRQqy6wRLCz/download/%D0%9F%D1%80%D0%B0%D0%B2%D0%B8%D0%BB%D0%B0_%D0%BF%D1%80%D0%B8%D0%B5%D0%BC%D0%B0_2025_%D0%90%D0%A1%D0%9F.pdf
#     Содержание: случае использования ЕПГУ для представления заявлений о приеме и документов,
# необходимых для поступления, МГТУ «СТАНКИН» вправе не проводить прием
# заявлений и документов посредством электронной информационной системы МГТУ
# «СТАНКИН».
# МГТУ «СТАНКИН» устанавливает места для приема заявлений и докум...
#
# [2] Дистанция: 0.3070
#     Источник: https://newcloud.stankin.ru/s/YozjQrwrYcGeDF3/download/%D0%9F%D1%80%D0%B0%D0%B2%D0%B8%D0%BB%D0%B0_%D0%BF%D1%80%D0%B8%D1%91%D0%BC%D0%B0_2025_%D0%91%D0%A1%D0%9C.pdf
#     Содержание: ЕПГУ).
# МГТУ «СТАНКИН» обеспечивает возможность представления (направления)
# заявлений и документов, необходимых для поступления, всеми указанными способами. В
# случае использования ЕПГУ для представления заявлений о приеме и документов,
# необходимых для поступления, МГТУ «СТАНКИН» вправе не проводи...
#
# [3] Дистанция: 0.3173
#     Источник: https://newcloud.stankin.ru/s/sndBbRQqy6wRLCz/download/%D0%9F%D1%80%D0%B0%D0%B2%D0%B8%D0%BB%D0%B0_%D0%BF%D1%80%D0%B8%D0%B5%D0%BC%D0%B0_2025_%D0%90%D0%A1%D0%9F.pdf
#     Содержание: их приема.
# Приём заявлений и документов, представляемых в МГТУ «СТАНКИН» лично
# поступающими, осуществляется по адресу Российская Федерация, г. Москва, Вадковский
# пер., д. 1, Приёмная комиссия, в часы работы Приёмной комиссии.
# В случае если заявление о приеме и документы, необходимые для поступл...
#
# [4] Дистанция: 0.3225
#     Источник: https://newcloud.stankin.ru/s/YozjQrwrYcGeDF3/download/%D0%9F%D1%80%D0%B0%D0%B2%D0%B8%D0%BB%D0%B0_%D0%BF%D1%80%D0%B8%D1%91%D0%BC%D0%B0_2025_%D0%91%D0%A1%D0%9C.pdf
#     Содержание: В случае если заявление о приеме и документы, необходимые для поступления,
# представляются в МГТУ «СТАНКИН» лично поступающим, поступающему выдается
# расписка в приеме заявления и документов.
# 70. При приеме на обучение по программам бакалавриата и программам специалитета
# МГТУ «СТАНКИН» устанавлива...
#
# [5] Дистанция: 0.3226
#     Источник: https://priem.stankin.ru/bakalavriatispetsialitet/submit_documents_bs/
#     Содержание: БС Подача документов ☰ Выберите способ подачи документов Портал госуслуг Дистанционно Почтовой связью очно Максимальное количество направлений подготовки для одновременного участия в конкурсе равно 5 . Поступающим прохождение медицинского осмотра и предоставления медицинских справок НЕ ТРЕБУЕТСЯ . О...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# 2025-12-14 16:59:57,630 - CRITICAL -
# --- 5 САМЫХ РЕЛЕВАНТНЫХ ЧАНКОВ (RAG-РЕЗУЛЬТАТ) ---
#
# 2025-12-14 16:59:57,631 - INFO - --------------------------------------------------
# 2025-12-14 16:59:57,632 - INFO - --------------------------------------------------
# 2025-12-14 16:59:57,633 - INFO - НАЧАЛО ТЕСТИРОВАНИЯ КАЧЕСТВА RAG
# 2025-12-14 16:59:57,634 - INFO - Тестовый запрос: 'Сколько баллов дают за индивидуальные достижения?'
# [1] Дистанция: 0.4022
#     Источник: https://newcloud.stankin.ru/s/sndBbRQqy6wRLCz/download/%D0%9F%D1%80%D0%B0%D0%B2%D0%B8%D0%BB%D0%B0_%D0%BF%D1%80%D0%B8%D0%B5%D0%BC%D0%B0_2025_%D0%90%D0%A1%D0%9F.pdf
#     Содержание: достижений,
# учитываемых
# при
# равенстве
# поступающих
# по
# иным
# критериям
# ранжирования
# в
# конкурсных
# списках,
# устанавливается
# МГТУ
# «СТАНКИН»
# самостоятельно.
# IV. Прием заявлений и документов
# 31. Поступающий на обучение подает:
# – одно заявление о приеме на места в рамках контрольных цифр пр...
#
# [2] Дистанция: 0.4039
#     Источник: https://priem.stankin.ru/bakalavriatispetsialitet/nap/09.03.04/
#     Содержание: балл в 2023 г. 238 проходной балл в 2022 г. Медианный балл медианный балл – балл абитуриента, находящегося в приказе о зачислении в 2024 году ровно посередине. 261 балла МИНИМАЛЬНЫЕ БАЛЛЫ минимальный балл – это минимальное количество баллов по общеобразовательным предметам для поступающих на 1 курс ...
#
# [3] Дистанция: 0.4053
#     Источник: https://priem.stankin.ru/magistratura/napravleniya/15.04.05/
#     Содержание: минимальное количество баллов по вступительному экзамену для поступающих на 1 курс 40 баллов Вступительные испытания Экзамен на направление 15.04.05 Конструкторско-технологическое обеспечение машиностроительных производств проходит в две волны, но сдавать экзамен можно только в одну из дат. Консульт...
#
# [4] Дистанция: 0.4064
#     Источник: https://newcloud.stankin.ru/s/YozjQrwrYcGeDF3/download/%D0%9F%D1%80%D0%B0%D0%B2%D0%B8%D0%BB%D0%B0_%D0%BF%D1%80%D0%B8%D1%91%D0%BC%D0%B0_2025_%D0%91%D0%A1%D0%9C.pdf
#     Содержание: поступать на указанные места);
# − документы, необходимые для поступления.
# 68. Поступающий на обучение по программам магистратуры подает:
# − одно заявление о приеме на места в рамках контрольных цифр приема (если он
# хочет поступать на указанные места);...
#
# [5] Дистанция: 0.4102
#     Источник: https://priem.stankin.ru/bakalavriatispetsialitet/nap/15.03.06/
#     Содержание: балл в 2023 г. 215 проходной балл в 2022 г. Медианный балл медианный балл – балл абитуриента, находящегося в приказе о зачислении в 2024 году ровно посередине. 233 балла МИНИМАЛЬНЫЕ БАЛЛЫ минимальный балл – это минимальное количество баллов по общеобразовательным предметам для поступающих на 1 курс ...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# 2025-12-14 16:59:57,675 - CRITICAL -
# --- 5 САМЫХ РЕЛЕВАНТНЫХ ЧАНКОВ (RAG-РЕЗУЛЬТАТ) ---
#
# 2025-12-14 16:59:57,676 - INFO - --------------------------------------------------
# 2025-12-14 16:59:57,677 - INFO - --------------------------------------------------
# 2025-12-14 16:59:57,677 - INFO - НАЧАЛО ТЕСТИРОВАНИЯ КАЧЕСТВА RAG
# 2025-12-14 16:59:57,678 - INFO - Тестовый запрос: 'Какие направления подготовки бакалавриата есть в Станкине?'
# [1] Дистанция: 0.3603
#     Источник: https://newcloud.stankin.ru/s/YozjQrwrYcGeDF3/download/%D0%9F%D1%80%D0%B0%D0%B2%D0%B8%D0%BB%D0%B0_%D0%BF%D1%80%D0%B8%D1%91%D0%BC%D0%B0_2025_%D0%91%D0%A1%D0%9C.pdf
#     Содержание: уменьшению классов, за которые они участвовали в указанных олимпиадах;
# б) по убыванию количества баллов за индивидуальные достижения (при приеме на
# обучение на места в пределах целевой квоты количество баллов за индивидуальные
# достижения исчисляется как сумма количества баллов за общие индивидуал...
#
# [2] Дистанция: 0.3621
#     Источник: https://newcloud.stankin.ru/s/sndBbRQqy6wRLCz/download/%D0%9F%D1%80%D0%B0%D0%B2%D0%B8%D0%BB%D0%B0_%D0%BF%D1%80%D0%B8%D0%B5%D0%BC%D0%B0_2025_%D0%90%D0%A1%D0%9F.pdf
#     Содержание: 52.
# Поступающие,
# включенные
# в
# конкурсный
# список,
# ранжируются
# последовательно по следующим основаниям:
# – по убыванию суммы конкурсных баллов;
# – по убыванию количества баллов за вступительные испытания;
# – по убыванию количества баллов за индивидуальные достижения (при приеме на
# обучение на ...
#
# [3] Дистанция: 0.3690
#     Источник: https://newcloud.stankin.ru/s/sndBbRQqy6wRLCz/download/%D0%9F%D1%80%D0%B0%D0%B2%D0%B8%D0%BB%D0%B0_%D0%BF%D1%80%D0%B8%D0%B5%D0%BC%D0%B0_2025_%D0%90%D0%A1%D0%9F.pdf
#     Содержание: целевой квоты в дополнение к баллам за общие индивидуальные достижения;
# 2) МГТУ «СТАНКИН» учитывает индивидуальные достижения при равенстве
# поступающих по иным критериям ранжирования в конкурсных списках.
# 29. МГТУ «СТАНКИН» устанавливает:
# – перечень общих индивидуальных достижений и порядок их у...
#
# [4] Дистанция: 0.3734
#     Источник: https://newcloud.stankin.ru/s/YozjQrwrYcGeDF3/download/%D0%9F%D1%80%D0%B0%D0%B2%D0%B8%D0%BB%D0%B0_%D0%BF%D1%80%D0%B8%D1%91%D0%BC%D0%B0_2025_%D0%91%D0%A1%D0%9C.pdf
#     Содержание: самостоятельно.
# IV. Учет индивидуальных достижений поступающих
# 53. Учет индивидуальных достижений поступающих осуществляется следующими
# способами:...
#
# [5] Дистанция: 0.3858
#     Источник: https://newcloud.stankin.ru/s/sndBbRQqy6wRLCz/download/%D0%9F%D1%80%D0%B0%D0%B2%D0%B8%D0%BB%D0%B0_%D0%BF%D1%80%D0%B8%D0%B5%D0%BC%D0%B0_2025_%D0%90%D0%A1%D0%9F.pdf
#     Содержание: 49. В конкурсном списке указываются следующие сведения:
# 1) уникальный код, присвоенный поступающему (далее - уникальный код
# поступающего);
# 2) сумма конкурсных баллов;
# 3) сумма баллов за вступительные испытания;
# 4) количество баллов за общие индивидуальные достижения;
# 5) количество баллов за це...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# 2025-12-14 16:59:57,720 - CRITICAL -
# --- 5 САМЫХ РЕЛЕВАНТНЫХ ЧАНКОВ (RAG-РЕЗУЛЬТАТ) ---
#
# 2025-12-14 16:59:57,721 - INFO - --------------------------------------------------
# 2025-12-14 16:59:57,722 - INFO - --------------------------------------------------
# 2025-12-14 16:59:57,723 - INFO - НАЧАЛО ТЕСТИРОВАНИЯ КАЧЕСТВА RAG
# 2025-12-14 16:59:57,723 - INFO - Тестовый запрос: 'Когда начинаются вступительные испытания в магистратуре?'
# [1] Дистанция: 0.3491
#     Источник: https://priem.stankin.ru/bakalavriatispetsialitet/info_perv_2025/
#     Содержание: 1 курса бакалавриата и специалитета! Организационные собрания студентов 1 курса бакалавриата и специалитета будут проводиться в следующие сроки: --- НАЧАЛО ТАБЛИЦЫ --- | Unnamed: 0 | Unnamed: 1 | Unnamed: 2 | |-------------:|:---------------------------------------------------------------------|:---...
#
# [2] Дистанция: 0.3575
#     Источник: https://newcloud.stankin.ru/s/YozjQrwrYcGeDF3/download/%D0%9F%D1%80%D0%B0%D0%B2%D0%B8%D0%BB%D0%B0_%D0%BF%D1%80%D0%B8%D1%91%D0%BC%D0%B0_2025_%D0%91%D0%A1%D0%9C.pdf
#     Содержание: настоящей главой.
# Сроки приема на обучение, которые не установлены настоящей главой,
# устанавливаются МГТУ «СТАНКИН» самостоятельно.
# 130. При приеме на обучение на места в рамках контрольных цифр приема по
# программам бакалавриата и программам специалитета по всем формам обучения:
# 1) прием заявле...
#
# [3] Дистанция: 0.3630
#     Источник: https://priem.stankin.ru/aspirantura/raspisanievvi/
#     Содержание: А Расписание ВВИ ☰ расписание вступительных экзаменов для поступающих на 1 курс по программам подготовки Аспирантуры В рамках платной основы экзамен по всем направлениям будет проходить 05.09.2025 в 10:00. Напоминаем, что экзамены проходят дистанционно По организационным вопросам обращайтесь в приём...
#
# [4] Дистанция: 0.3652
#     Источник: https://newcloud.stankin.ru/s/sndBbRQqy6wRLCz/download/%D0%9F%D1%80%D0%B0%D0%B2%D0%B8%D0%BB%D0%B0_%D0%BF%D1%80%D0%B8%D0%B5%D0%BC%D0%B0_2025_%D0%90%D0%A1%D0%9F.pdf
#     Содержание: обучение, программы аспирантуры), в том числе особенности проведения вступительных
# испытаний для инвалидов на 2025/2026 учебный год.
# 2. МГТУ «СТАНКИН» объявляет прием на обучение по программам аспирантуры
# (далее – прием на обучение) в соответствии с лицензией на осуществление
# образовательной дея...
#
# [5] Дистанция: 0.3704
#     Источник: https://priem.stankin.ru/magistratura/raspisanievvi/
#     Содержание: М Расписание ВВИ ☰ расписание консультаций И ЭКЗАМЕНОВ для поступающих на 1 курс по программам подготовки магистратуры В рамках платной основы экзамен по всем направлениям будет проходить 05.09.2025 в 10:00. Напоминаем, что экзамены проходят дистанционно По организационным вопросам обращайтесь в при...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# 2025-12-14 16:59:57,765 - CRITICAL -
# --- 5 САМЫХ РЕЛЕВАНТНЫХ ЧАНКОВ (RAG-РЕЗУЛЬТАТ) ---
#
# 2025-12-14 16:59:57,767 - INFO - --------------------------------------------------
# [1] Дистанция: 0.3041
#     Источник: https://newcloud.stankin.ru/s/YozjQrwrYcGeDF3/download/%D0%9F%D1%80%D0%B0%D0%B2%D0%B8%D0%BB%D0%B0_%D0%BF%D1%80%D0%B8%D1%91%D0%BC%D0%B0_2025_%D0%91%D0%A1%D0%9C.pdf
#     Содержание: необходимо сдавать внутренние вступительные испытания (далее – день завершения
# приема документов со сдачей вступительных испытаний);...
#
# [2] Дистанция: 0.3637
#     Источник: https://newcloud.stankin.ru/s/YozjQrwrYcGeDF3/download/%D0%9F%D1%80%D0%B0%D0%B2%D0%B8%D0%BB%D0%B0_%D0%BF%D1%80%D0%B8%D1%91%D0%BC%D0%B0_2025_%D0%91%D0%A1%D0%9C.pdf
#     Содержание: − по убыванию количества баллов за отдельные вступительные испытания в
# соответствии
# с
# приоритетностью
# испытаний
# при
# ранжировании.
# Университет
# устанавливает
# следующую
# приоритетность
# вступительных
# испытаний,
# которая...
#
# [3] Дистанция: 0.3652
#     Источник: https://newcloud.stankin.ru/s/YozjQrwrYcGeDF3/download/%D0%9F%D1%80%D0%B0%D0%B2%D0%B8%D0%BB%D0%B0_%D0%BF%D1%80%D0%B8%D1%91%D0%BC%D0%B0_2025_%D0%91%D0%A1%D0%9C.pdf
#     Содержание: при сдаче ими вступительных испытаний). Способ регламентируется отдельным
# Университетом самостоятельно.
# 42. Результаты внутренних вступительных испытаний действительны при приеме на
# обучение на учебный год, на который осуществляется прием на обучение.
# 43. Поступающий сдает каждое внутреннее всту...
#
# [4] Дистанция: 0.3768
#     Источник: https://newcloud.stankin.ru/s/3X3GL68qHBRZnKN/download/2025_%D0%9F%D0%BE%D1%80%D1%8F%D0%B4%D0%BE%D0%BA_%D0%BF%D1%80%D0%BE%D0%B2%D0%B5%D0%B4%D0%B5%D0%BD%D0%B8%D1%8F_%D0%B2%D1%81%D1%82%D1%83%D0%BF%D0%B8%D1%82%D0%B5%D0%BB%D1%8C%D0%BD%D1%8B%D1%85_%D0%B8%D1%81%D0%BF%D1%8B%D1%82%D0%B0%D0%BD%D0%B8%D0%B9_%D0%B2_%D0%B1%D0%B0%D0%BA,_%D1%81%D0%BF%D0%B5%D1%86.pdf
#     Содержание: В случае, если по итогам проверки выявлено, что процедура идентификации
# личности прошла с нарушениями, работа экзаменующегося аннулируется, о чём
# одновременно составляется акт, подписываемый сотрудниками рабочей группы приемной
# комиссии, наблюдающими за ходом экзамена.
# 2.5.
# Доступ к прокторингу...
#
# [5] Дистанция: 0.3791
#     Источник: https://priem.stankin.ru/magistratura/napravleniya/15.04.05.02_rpc/
#     Содержание: профильный экзамен "Роботизированные обрабатывающие комплексы " Профили Роботизированные обрабатывающие комплексы ( Передовая инженерная школа ) Кафедра: Станки Учебный план Узнать подробнее о профиле МИНИМАЛЬНЫй БАЛЛ минимальный балл – это минимальное количество баллов по вступительному экзамену дл...

# %%
test_rag_query("Что нужно сдавать для того чтобы поступить на направление 09.03.03", ef)
# Out:
# 2025-12-14 17:03:35,244 - INFO - --------------------------------------------------
# 2025-12-14 17:03:35,245 - INFO - НАЧАЛО ТЕСТИРОВАНИЯ КАЧЕСТВА RAG
# 2025-12-14 17:03:35,246 - INFO - Тестовый запрос: 'Что нужно сдавать для того чтобы поступить на направление 09.03.03'
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# 2025-12-14 17:03:35,326 - CRITICAL -
# --- 5 САМЫХ РЕЛЕВАНТНЫХ ЧАНКОВ (RAG-РЕЗУЛЬТАТ) ---
#
# 2025-12-14 17:03:35,329 - INFO - --------------------------------------------------
# [1] Дистанция: 0.3823
#     Источник: https://priem.stankin.ru/bakalavriatispetsialitet/info_perv_2025/
#     Содержание: до 18.00 ( для заселения в день получения ордера необходимо получить ордер с 9.00 до 14.00 , заселиться в общежитие можно только с понедельника по пятницу) при предъявлении паспорта. Единый деканат находится в здании по адресу Вадковский пер., д. 3а. При входе в здание по адресу Вадковский пер., д. ...
#
# [2] Дистанция: 0.3959
#     Источник: https://priem.stankin.ru/bakalavriatispetsialitet/info_perv_2025/
#     Содержание: 2025 года | 09.03.02 и 15.05.01 | | nan | начиная с 28 августа 2025 года | 09.03.03, 15.03.01, 15.03.02, 27.03.01 | | nan | начиная с 29 августа 2025 года | 12.03.01, 15.03.05 | --- КОНЕЦ ТАБЛИЦЫ --- ВАЖНО: Сначала надо получить ордер, а только потом можно заселяться в общежитие Ордера выдаются в Ед...
#
# [3] Дистанция: 0.3976
#     Источник: https://newcloud.stankin.ru/s/sk5ermw7k9Kdxxs/download/2025_%D0%9F%D0%BE%D1%80%D1%8F%D0%B4%D0%BE%D0%BA_%D0%BF%D1%80%D0%BE%D0%B2%D0%B5%D0%B4%D0%B5%D0%BD%D0%B8%D1%8F_%D0%B2%D1%81%D1%82%D1%83%D0%BF%D0%B8%D1%82%D0%B5%D0%BB%D1%8C%D0%BD%D1%8B%D1%85_%D0%B8%D1%81%D0%BF%D1%8B%D1%82%D0%B0%D0%BD%D0%B8%D0%B9_%D0%B2_%D0%B0%D1%81%D0%BF%D0%B8%D1%80%D0%B0%D0%BD%D1%82%D1%83%D1%80%D1%83.pdf
#     Содержание: 4.3. На листах работы не должно присутствовать каких-либо персональных данных
# поступающего.
# 4.4. По завершению подготовки ответов на вопросы на дистанционном ВИ необходимо...
#
# [4] Дистанция: 0.4020
#     Источник: https://newcloud.stankin.ru/s/3X3GL68qHBRZnKN/download/2025_%D0%9F%D0%BE%D1%80%D1%8F%D0%B4%D0%BE%D0%BA_%D0%BF%D1%80%D0%BE%D0%B2%D0%B5%D0%B4%D0%B5%D0%BD%D0%B8%D1%8F_%D0%B2%D1%81%D1%82%D1%83%D0%BF%D0%B8%D1%82%D0%B5%D0%BB%D1%8C%D0%BD%D1%8B%D1%85_%D0%B8%D1%81%D0%BF%D1%8B%D1%82%D0%B0%D0%BD%D0%B8%D0%B9_%D0%B2_%D0%B1%D0%B0%D0%BA,_%D1%81%D0%BF%D0%B5%D1%86.pdf
#     Содержание: образования программам магистратуры продолжительность вступительного испытания по
# следующим направлениям подготовки 09.04.01 «Информатика и вычислительная техника»,
# 09.04.04 «Программная инженерия» составляет 90 минут.
# 4.13. Для поступающих на обучение по образовательным программам высшего
# образ...
#
# [5] Дистанция: 0.4022
#     Источник: https://newcloud.stankin.ru/s/3X3GL68qHBRZnKN/download/2025_%D0%9F%D0%BE%D1%80%D1%8F%D0%B4%D0%BE%D0%BA_%D0%BF%D1%80%D0%BE%D0%B2%D0%B5%D0%B4%D0%B5%D0%BD%D0%B8%D1%8F_%D0%B2%D1%81%D1%82%D1%83%D0%BF%D0%B8%D1%82%D0%B5%D0%BB%D1%8C%D0%BD%D1%8B%D1%85_%D0%B8%D1%81%D0%BF%D1%8B%D1%82%D0%B0%D0%BD%D0%B8%D0%B9_%D0%B2_%D0%B1%D0%B0%D0%BA,_%D1%81%D0%BF%D0%B5%D1%86.pdf
#     Содержание: пустую письменную работу поступающего.
# 4.15. В случае не завершения тестирования в указанные сроки, считается, что
# поступающий участвовал в ВИ и сдал пустую работу поступающего, оцениваемую в 0 баллов.
#
# 5. Требования к оформлению письменной работы поступающего в магистратуру:
#
# 5.1.
# Письменная...
