# %%
import os
import re
import logging
import requests
import pandas as pd
from bs4 import BeautifulSoup
from urllib.parse import urlparse, urljoin
from transformers import AutoTokenizer, AutoModel
import torch
import chromadb
from chromadb import Documents, EmbeddingFunction, Embeddings
from sentence_transformers import SentenceTransformer
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %%
# --- КОНФИГУРАЦИЯ ---
# Настройка логирования
logging.basicConfig(level=logging.INFO,
                    format='%(asctime)s - %(levelname)s - %(message)s')

class STANKIN_RAG_Config:
    START_URL = "https://priem.stankin.ru/"
    BASE_DOMAIN = urlparse(START_URL).netloc
    MAX_CRAWL_DEPTH = 4
    EMBEDDING_MODEL_NAME = "cointegrated/rubert-tiny2"
    CHROMA_DB_PATH = "./stankin_db"
    COLLECTION_NAME = "stankin_collection"
    
    # Параметры чанкинга
    CHUNK_SIZE = 1000  # Используем больше, но фильтр по длине все равно сработает
    CHUNK_OVERLAP = 100
    MIN_CHUNK_LEN = 50
    MAX_CHUNK_LEN = 3000
    
    # Регулярные выражения для Анти-Мусор Фильтра (Требование 2.C)
    ANTI_GARBAGE_PATTERNS = [
        re.compile(r'data:image/[a-zA-Z0-9+/=;,-]+'),  # Base64 строки
        re.compile(r'', re.DOTALL),          # HTML комментарии
        re.compile(r'\[Top\.Mail\.Ru\]|Yandex\.Metrika'), # Счетчики/Аналитика
        re.compile(r'^\s*https?://\S+\s*$')              # Чанк - это просто URL
    ]

# %%
# --- МОДУЛЬ 1: ВЕКТОРИЗАЦИЯ (ОБНОВЛЕННЫЙ) ---
class SBERT_EmbeddingFunction(EmbeddingFunction):
    """
    Использует SentenceTransformer для надежной загрузки DeepPavlov модели,
    гарантируя корректный пулинг и нормализацию.
    """
    def __init__(self, model_name: str):
        logging.info(f"Загрузка модели через SentenceTransformer: {model_name}...")
        try:
            # SentenceTransformer автоматически обрабатывает pooling и нормализацию
            self.model = SentenceTransformer(model_name)
            logging.info("SUCCESS: Функция эмбеддинга (SBERT) успешно инициализирована.")
        except Exception as e:
            logging.critical(f"КРИТИЧЕСКАЯ ОШИБКА ЗАГРУЗКИ SBERT: {e}")
            raise

    def __call__(self, texts: Documents) -> Embeddings:
        """Генерирует эмбеддинги."""
        # encode возвращает L2-нормализованные векторы numpy
        embeddings = self.model.encode(texts, convert_to_numpy=True)
        return embeddings.tolist()

# %%
# --- МОДУЛЬ 2: КРАУЛИНГ И ОЧИСТКА ---

def clean_html_content(html_content: str, url: str) -> str:
    """
    Агрессивная очистка HTML: удаление служебных тегов, 
    конвертация таблиц в Markdown.
    """
    soup = BeautifulSoup(html_content, 'lxml')
    
    # 1. Удаление служебных тегов
    REMOVAL_TAGS = ['script', 'style', 'nav', 'footer', 'header', 'form', 'aside', 'iframe', 'noscript']
    for tag in REMOVAL_TAGS:
        for element in soup.find_all(tag):
            element.decompose()
    logging.debug(f"Удалены служебные теги на {url}")

    # 2. Обработка Таблиц (Преобразование в Markdown)
    tables = soup.find_all('table')
    if tables:
        logging.info(f"Обработка {len(tables)} таблиц на странице {url}...")
        for i, table in enumerate(tables):
            try:
                # pandas.read_html может парсить как строку, так и тег
                df = pd.read_html(str(table))[0]
                # Конвертация в Markdown
                markdown_table = "\n\n--- НАЧАЛО ТАБЛИЦЫ ---\n"
                markdown_table += df.to_markdown(index=False)
                markdown_table += "\n--- КОНЕЦ ТАБЛИЦЫ ---\n\n"
                
                # Заменяем тег <table> на его Markdown представление
                table.replace_with(BeautifulSoup(markdown_table, 'html.parser'))
            except Exception as e:
                logging.warning(f"Ошибка парсинга таблицы {i+1} на {url}: {e}")
                table.decompose() # Удаляем проблемную таблицу

    # 3. Финальная очистка текста
    # Получаем чистый текст из оставшегося HTML
    text = soup.get_text(separator=' ', strip=True)
    # Удаляем лишние пробелы и переводы строк
    text = re.sub(r'\s+', ' ', text).strip()
    
    logging.debug(f"HTML-контент страницы {url} очищен. Длина: {len(text)}")
    return text

# %%
def stankin_crawler(start_url: str, max_depth: int) -> dict:
    """
    Рекурсивный краулинг с ограничением по домену и глубине.
    Возвращает словарь {url: content}.
    """
    queue = [(start_url, 0)]
    visited = {start_url}
    page_contents = {}
    base_domain = STANKIN_RAG_Config.BASE_DOMAIN
    
    logging.info(f"Запуск краулинга с {start_url} до глубины {max_depth}...")

    while queue:
        current_url, depth = queue.pop(0)

        if depth > max_depth:
            continue
        
        logging.info(f"-> Парсинг URL: {current_url} (Глубина: {depth})")

        try:
            response = requests.get(current_url, timeout=10)
            # Проверяем успешность и кодировку
            response.raise_for_status()
            response.encoding = response.apparent_encoding 
            
            html_content = response.text
            
            # 1. Очищаем контент
            cleaned_text = clean_html_content(html_content, current_url)
            page_contents[current_url] = cleaned_text
            
            # 2. Поиск новых ссылок
            soup = BeautifulSoup(html_content, 'lxml')
            for link in soup.find_all('a', href=True):
                href = link['href']
                absolute_url = urljoin(current_url, href).split('#')[0] # Убираем якоря
                
                # Проверка на поддомен и посещение
                if urlparse(absolute_url).netloc == base_domain and absolute_url not in visited:
                    visited.add(absolute_url)
                    queue.append((absolute_url, depth + 1))
                    logging.debug(f"DEBUG: Найдена новая ссылка: {absolute_url} (Depth: {depth + 1})")
            
        except requests.exceptions.RequestException as e:
            logging.error(f"Ошибка при загрузке {current_url}: {e}")
        except Exception as e:
            logging.error(f"Непредвиденная ошибка на {current_url}: {e}")

    logging.info(f"SUCCESS: Краулинг завершен. Найдено {len(page_contents)} уникальных страниц.")
    return page_contents

# %%
# --- МОДУЛЬ 3: ЧАНКИНГ И ФИЛЬТРАЦИЯ ---

def create_and_filter_chunks(page_contents: dict) -> list[dict]:
    """
    Разбивает текст на чанки и применяет двойную фильтрацию.
    Возвращает список словарей {text, source}.
    """
    # Инициализация LangChain Text Splitter
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=STANKIN_RAG_Config.CHUNK_SIZE,
        chunk_overlap=STANKIN_RAG_Config.CHUNK_OVERLAP,
        separators=["\n\n", "\n", " ", ""],
        length_function=len
    )
    
    final_chunks = []
    
    logging.info("Применение чанкинга и двойного фильтра ко всему контенту...")

    for url, text in page_contents.items():
        if not text:
            logging.warning(f"Пропущен пустой контент для URL: {url}")
            continue

        # 1. Разбиение на чанки
        chunks = text_splitter.split_text(text)
        logging.info(f"URL: {url} -> Исходный текст разбит на {len(chunks)} чанков.")
        
        for i, chunk in enumerate(chunks):
            # 2. Фильтр 1: По длине (Требование 2.C)
            if not (STANKIN_RAG_Config.MIN_CHUNK_LEN <= len(chunk) <= STANKIN_RAG_Config.MAX_CHUNK_LEN):
                logging.debug(f"CHUNK FILTER (Length): Пропущен чанк #{i} (Длина: {len(chunk)}).")
                continue

            '''
            # 3. Фильтр 2: Анти-Мусор (Требование 2.C)
            is_garbage = False
            for pattern in STANKIN_RAG_Config.ANTI_GARBAGE_PATTERNS:
                if pattern.search(chunk):
                    logging.warning(f"CHUNK FILTER (Garbage): Пропущен чанк #{i} из {url} (Начало: {chunk[:50]}...)")
                    is_garbage = True
                    break
            
            if is_garbage:
                continue
            '''

            # Если чанк прошел все фильтры
            final_chunks.append({
                "text": chunk,
                "source": url
            })

    logging.info(f"SUCCESS: Итоговое количество чанков, готовых к индексированию: {len(final_chunks)}")
    return final_chunks

# %%
# --- МОДУЛЬ 4: ИНДЕКСИРОВАНИЕ ---

def index_chunks_to_chroma(chunks: list[dict], ef: EmbeddingFunction):
    """
    Индексирует очищенные чанки в ChromaDB.
    """
    logging.info(f"Инициализация ChromaDB по пути: {STANKIN_RAG_Config.CHROMA_DB_PATH}")
    client = chromadb.PersistentClient(path=STANKIN_RAG_Config.CHROMA_DB_PATH)
    collection_name = STANKIN_RAG_Config.COLLECTION_NAME
    
    # Требование 2.D: Удаление существующей коллекции
    try:
        client.delete_collection(name=collection_name)
        logging.critical(f"Удалена старая коллекция '{collection_name}' для чистого старта.")
    except:
        logging.info(f"Коллекция '{collection_name}' не найдена или не требует удаления.")

    # Создание новой коллекции с кастомной функцией эмбеддинга
    collection = client.get_or_create_collection(
        name=collection_name, 
        embedding_function=ef,
        metadata={"hnsw:space": "cosine"}
    )
    logging.info(f"Коллекция '{collection_name}' готова к заполнению.")

    # Подготовка данных для пакетного добавления
    documents = [c['text'] for c in chunks]
    metadatas = [{"source": c['source']} for c in chunks]
    # ID's должны быть уникальными (например, URL + индекс чанка)
    ids = [f"{i}-{re.sub(r'[^a-zA-Z0-9]', '_', c['source'])}" for i, c in enumerate(chunks)]

    if not documents:
        logging.warning("Нет документов для индексирования. Пропускаем.")
        return

    # Пакетное добавление
    BATCH_SIZE = 500 
    for i in range(0, len(documents), BATCH_SIZE):
        batch_docs = documents[i:i + BATCH_SIZE]
        batch_metadatas = metadatas[i:i + BATCH_SIZE]
        batch_ids = ids[i:i + BATCH_SIZE]
        
        collection.add(
            documents=batch_docs,
            metadatas=batch_metadatas,
            ids=batch_ids
        )
        logging.info(f"Индексирован пакет: {i} - {min(i + BATCH_SIZE, len(documents))}")
    
    logging.critical(f"SUCCESS: Индексирование завершено. Всего чанков в БД: {collection.count()}")

# %%
# --- МОДУЛЬ 5: ТЕСТИРОВАНИЕ RAG ---

def test_rag_query(query: str, ef: EmbeddingFunction):
    """
    Выполняет тестовый запрос и выводит результаты.
    """
    logging.info("-" * 50)
    logging.info("НАЧАЛО ТЕСТИРОВАНИЯ КАЧЕСТВА RAG")
    logging.info(f"Тестовый запрос: '{query}'")
    
    client = chromadb.PersistentClient(path=STANKIN_RAG_Config.CHROMA_DB_PATH)
    collection_name = STANKIN_RAG_Config.COLLECTION_NAME
    
    try:
        # Получаем коллекцию (с обязательным указанием EF, чтобы запрос кодировался корректно)
        collection = client.get_collection(name=collection_name, embedding_function=ef)
    except Exception as e:
        logging.error(f"Коллекция не найдена. Невозможно выполнить тест. {e}")
        return

    # Выполняем семантический поиск
    results = collection.query(
        query_texts=[query],
        n_results=5, # Требование 2.D
        include=['documents', 'metadatas', 'distances']
    )

    if not results or not results['documents'] or not results['documents'][0]:
        logging.error("Не найдено релевантных документов.")
        return

    logging.critical("\n--- 5 САМЫХ РЕЛЕВАНТНЫХ ЧАНКОВ (RAG-РЕЗУЛЬТАТ) ---\n")
    
    for i in range(5):
        try:
            distance = results['distances'][0][i]
            source = results['metadatas'][0][i]['source']
            content = results['documents'][0][i]
            
            print(f"[{i+1}] Дистанция: {distance:.4f}")
            print(f"    Источник: {source}")
            print(f"    Содержание: {content[:300]}...\n")
            
        except IndexError:
            # Если найдено меньше 5 результатов
            break
            
    logging.info("-" * 50)

# %%
# --- ОСНОВНАЯ ФУНКЦИЯ ЗАПУСКА ---

def main():
    logging.critical("СТАРТ RAG-СИСТЕМЫ ПАРСИНГА СТАНКИНА")
    
    # ШАГ 1: Инициализация Embedding Function (Ключевое требование)
    try:
        # ИСПОЛЬЗУЕМ НОВЫЙ КЛАСС: SBERT_EmbeddingFunction
        ef = SBERT_EmbeddingFunction(STANKIN_RAG_Config.EMBEDDING_MODEL_NAME) 
    except Exception as e:
        logging.critical(f"КРИТИЧЕСКАЯ ОШИБКА ИНИЦИАЛИЗАЦИИ МОДЕЛИ: {e}")
        return

    # ШАГ 2: Краулинг и Очистка
    page_contents = stankin_crawler(
        start_url=STANKIN_RAG_Config.START_URL,
        max_depth=STANKIN_RAG_Config.MAX_CRAWL_DEPTH
    )

    # ШАГ 3: Чанкинг и Двойная Фильтрация
    filtered_chunks = create_and_filter_chunks(page_contents)

    # ШАГ 4: Индексирование в ChromaDB
    if filtered_chunks:
        index_chunks_to_chroma(filtered_chunks, ef)
    
    # ШАГ 5: Тестирование RAG
    TEST_QUERY_1 = "Какие документы нужны для подачи заявления в МГТУ СТАНКИН?"
    TEST_QUERY_2 = "Сколько баллов нужно набрать, для того чтобы поступить на направление 09.03.03?"
    TEST_QUERY_3 = "Сколько баллов дают за индивидуальные достижения?"
    TEST_QUERY_4 = "Какие направления подготовки бакалавриата есть в Станкине?"
    TEST_QUERY_5 = "Когда начинаются вступительные испытания в магистратуре?"
    test_rag_query(TEST_QUERY_1, ef)
    test_rag_query(TEST_QUERY_2, ef)
    test_rag_query(TEST_QUERY_3, ef)
    test_rag_query(TEST_QUERY_4, ef)
    test_rag_query(TEST_QUERY_5, ef)

if __name__ == "__main__":
    # Создаем папку Data, если ее нет
    os.makedirs('Data', exist_ok=True) 
    # Запускаем основной процесс
    main()
# Out:
# 2025-12-14 14:48:52,574 - CRITICAL - СТАРТ RAG-СИСТЕМЫ ПАРСИНГА СТАНКИНА
# 2025-12-14 14:48:52,577 - INFO - Загрузка модели через SentenceTransformer: cointegrated/rubert-tiny2...
# 2025-12-14 14:48:52,581 - INFO - Use pytorch device_name: cpu
# 2025-12-14 14:48:52,582 - INFO - Load pretrained SentenceTransformer: cointegrated/rubert-tiny2
# 2025-12-14 14:48:55,681 - INFO - SUCCESS: Функция эмбеддинга (SBERT) успешно инициализирована.
# 2025-12-14 14:48:55,682 - INFO - Запуск краулинга с https://priem.stankin.ru/ до глубины 4...
# 2025-12-14 14:48:55,683 - INFO - -> Парсинг URL: https://priem.stankin.ru/ (Глубина: 0)
# 2025-12-14 14:48:56,381 - INFO - -> Парсинг URL: https://priem.stankin.ru/olympiads/ (Глубина: 1)
# 2025-12-14 14:48:57,004 - INFO - -> Парсинг URL: https://priem.stankin.ru/zadatvoprospk/ (Глубина: 1)
# 2025-12-14 14:48:57,500 - INFO - -> Парсинг URL: https://priem.stankin.ru/meropriyatiya/ (Глубина: 1)
# 2025-12-14 14:48:58,081 - INFO - -> Парсинг URL: https://priem.stankin.ru/rod_sobranie/ (Глубина: 1)
# 2025-12-14 14:48:58,650 - INFO - -> Парсинг URL: https://priem.stankin.ru/podkast_napravleniy/ (Глубина: 1)
# 2025-12-14 14:48:59,279 - INFO - -> Парсинг URL: https://priem.stankin.ru/_dod/ (Глубина: 1)
# 2025-12-14 14:48:59,896 - INFO - -> Парсинг URL: https://priem.stankin.ru/vseros_stankin/ (Глубина: 1)
# 2025-12-14 14:49:00,658 - INFO - -> Парсинг URL: https://priem.stankin.ru/vysokotochnaya_olimpiada/ (Глубина: 1)
# 2025-12-14 14:49:01,326 - INFO - -> Парсинг URL: https://priem.stankin.ru/stud_olymp/ (Глубина: 1)
# 2025-12-14 14:49:01,989 - INFO - -> Парсинг URL: https://priem.stankin.ru/youngschool/ (Глубина: 1)
# 2025-12-14 14:49:02,570 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/submit_documents_bs/ (Глубина: 1)
# 2025-12-14 14:49:03,087 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/training_programs/ (Глубина: 1)
# 2025-12-14 14:49:03,784 - INFO - Обработка 43 таблиц на странице https://priem.stankin.ru/bakalavriatispetsialitet/training_programs/...
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_13856\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_13856\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_13856\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_13856\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_13856\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_13856\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_13856\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_13856\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_13856\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_13856\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_13856\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_13856\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_13856\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_13856\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_13856\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_13856\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_13856\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_13856\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_13856\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_13856\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_13856\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_13856\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_13856\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_13856\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_13856\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_13856\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_13856\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_13856\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_13856\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_13856\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_13856\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_13856\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_13856\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_13856\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_13856\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_13856\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_13856\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_13856\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_13856\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_13856\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_13856\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_13856\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_13856\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# 2025-12-14 14:49:04,140 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/Individual_achievements/ (Глубина: 1)
# 2025-12-14 14:49:04,766 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/exam_schedule/ (Глубина: 1)
# 2025-12-14 14:49:05,402 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/exam_results/ (Глубина: 1)
# 2025-12-14 14:49:06,049 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/min_points/ (Глубина: 1)
# 2025-12-14 14:49:06,609 - INFO - Обработка 3 таблиц на странице https://priem.stankin.ru/bakalavriatispetsialitet/min_points/...
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_13856\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_13856\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_13856\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# 2025-12-14 14:49:06,664 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/programmavvi/ (Глубина: 1)
# 2025-12-14 14:49:07,243 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/formaprovedeniyaekzamenov/ (Глубина: 1)
# 2025-12-14 14:49:07,802 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/daty_priema/ (Глубина: 1)
# 2025-12-14 14:49:08,387 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/terms_of_admission_paid/ (Глубина: 1)
# 2025-12-14 14:49:08,972 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/special_rights/ (Глубина: 1)
# 2025-12-14 14:49:09,586 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/osobkvota/ (Глубина: 1)
# 2025-12-14 14:49:10,209 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/otdkvota/ (Глубина: 1)
# 2025-12-14 14:49:10,827 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/targeted_training/ (Глубина: 1)
# 2025-12-14 14:49:11,403 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/tselevayakvota/ (Глубина: 1)
# 2025-12-14 14:49:12,357 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/podborpredpriyatiyazakazchika/ (Глубина: 1)
# 2025-12-14 14:49:12,921 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/stoimostobucheniya/ (Глубина: 1)
# 2025-12-14 14:49:13,459 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/priemovz/ (Глубина: 1)
# 2025-12-14 14:49:14,000 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/programmaloyalnosti/ (Глубина: 1)
# 2025-12-14 14:49:14,588 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/stipendii_imln/ (Глубина: 1)
# 2025-12-14 14:49:15,164 - INFO - -> Парсинг URL: https://priem.stankin.ru/obshchezhitie/ (Глубина: 1)
# 2025-12-14 14:49:15,733 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/statistika/ (Глубина: 1)
# 2025-12-14 14:49:16,374 - INFO - Обработка 2 таблиц на странице https://priem.stankin.ru/bakalavriatispetsialitet/statistika/...
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_13856\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_13856\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# 2025-12-14 14:49:16,464 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/ranked-lists/ (Глубина: 1)
# 2025-12-14 14:49:16,971 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/ranked-lists-ext/?order=1 (Глубина: 1)
# 2025-12-14 14:49:17,536 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/name-lists/ (Глубина: 1)
# 2025-12-14 14:49:18,127 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/prikazy/ (Глубина: 1)
# 2025-12-14 14:49:18,736 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/ofitsialnyedokumenty/ (Глубина: 1)
# 2025-12-14 14:49:19,275 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/directions/ (Глубина: 1)
# 2025-12-14 14:49:19,812 - INFO - Обработка 1 таблиц на странице https://priem.stankin.ru/bakalavriatispetsialitet/directions/...
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_13856\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# 2025-12-14 14:49:19,849 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/zadatvoprospk/ (Глубина: 1)
# 2025-12-14 14:49:20,415 - INFO - -> Парсинг URL: https://priem.stankin.ru/TOP_IT/ (Глубина: 1)
# 2025-12-14 14:49:20,968 - INFO - -> Парсинг URL: https://priem.stankin.ru/magistratura/podachadokumentov/ (Глубина: 1)
# 2025-12-14 14:49:21,590 - INFO - -> Парсинг URL: https://priem.stankin.ru/magistratura/kcp_mag/ (Глубина: 1)
# 2025-12-14 14:49:22,183 - INFO - Обработка 19 таблиц на странице https://priem.stankin.ru/magistratura/kcp_mag/...
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_13856\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_13856\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_13856\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_13856\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_13856\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_13856\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_13856\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_13856\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_13856\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_13856\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_13856\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_13856\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_13856\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_13856\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_13856\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_13856\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_13856\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_13856\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_13856\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# 2025-12-14 14:49:22,329 - INFO - -> Парсинг URL: https://priem.stankin.ru/magistratura/id/ (Глубина: 1)
# 2025-12-14 14:49:22,968 - INFO - -> Парсинг URL: https://priem.stankin.ru/magistratura/targeted_training/ (Глубина: 1)
# 2025-12-14 14:49:23,559 - INFO - -> Парсинг URL: https://priem.stankin.ru/magistratura/podborpredpriyatiyazakazchika/ (Глубина: 1)
# 2025-12-14 14:49:24,126 - INFO - -> Парсинг URL: https://priem.stankin.ru/magistratura/tselevayakvota/ (Глубина: 1)
# 2025-12-14 14:49:24,735 - INFO - -> Парсинг URL: https://priem.stankin.ru/magistratura/datypriemabyudzhet/ (Глубина: 1)
# 2025-12-14 14:49:25,329 - INFO - -> Парсинг URL: https://priem.stankin.ru/magistratura/datypriemaplatka/ (Глубина: 1)
# 2025-12-14 14:49:25,882 - INFO - -> Парсинг URL: https://priem.stankin.ru/magistratura/cost/ (Глубина: 1)
# 2025-12-14 14:49:26,497 - INFO - -> Парсинг URL: https://priem.stankin.ru/magistratura/raspisanievvi/ (Глубина: 1)
# 2025-12-14 14:49:27,115 - INFO - -> Парсинг URL: https://priem.stankin.ru/magistratura/formaprovedeniyaekzamenov/ (Глубина: 1)
# 2025-12-14 14:49:27,713 - INFO - -> Парсинг URL: https://priem.stankin.ru/magistratura/programmavvi/ (Глубина: 1)
# 2025-12-14 14:49:28,326 - INFO - -> Парсинг URL: https://priem.stankin.ru/magistratura/results_vvi/ (Глубина: 1)
# 2025-12-14 14:49:28,972 - INFO - -> Парсинг URL: https://priem.stankin.ru/magistratura/stipendii/ (Глубина: 1)
# 2025-12-14 14:49:29,532 - INFO - -> Парсинг URL: https://priem.stankin.ru/magistratura/mprogrammaloyalnosti/ (Глубина: 1)
# 2025-12-14 14:49:30,101 - INFO - -> Парсинг URL: https://priem.stankin.ru/magistratura/priemgrazhdansovz/ (Глубина: 1)
# 2025-12-14 14:49:30,623 - INFO - -> Парсинг URL: https://priem.stankin.ru/magistratura/mstat/ (Глубина: 1)
# 2025-12-14 14:49:31,232 - INFO - Обработка 2 таблиц на странице https://priem.stankin.ru/magistratura/mstat/...
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_13856\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_13856\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# 2025-12-14 14:49:31,291 - INFO - -> Парсинг URL: https://priem.stankin.ru/magistratura/ranked-lists/ (Глубина: 1)
# 2025-12-14 14:49:31,874 - INFO - -> Парсинг URL: https://priem.stankin.ru/magistratura/ranked-lists-ext/?order=1 (Глубина: 1)
# 2025-12-14 14:49:32,471 - INFO - -> Парсинг URL: https://priem.stankin.ru/magistratura/name-lists/ (Глубина: 1)
# 2025-12-14 14:49:33,051 - INFO - -> Парсинг URL: https://priem.stankin.ru/magistratura/bsprikazy/ (Глубина: 1)
# 2025-12-14 14:49:33,637 - INFO - -> Парсинг URL: https://priem.stankin.ru/magistratura/ofitsialnyedokumenty/ (Глубина: 1)
# 2025-12-14 14:49:34,193 - INFO - -> Парсинг URL: https://priem.stankin.ru/magistratura/zadatvoprospk/ (Глубина: 1)
# 2025-12-14 14:49:34,742 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/podachadokumentov/ (Глубина: 1)
# 2025-12-14 14:49:35,348 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/programmyobucheniya/ (Глубина: 1)
# 2025-12-14 14:49:35,913 - INFO - Обработка 1 таблиц на странице https://priem.stankin.ru/aspirantura/programmyobucheniya/...
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_13856\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# 2025-12-14 14:49:35,979 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/id/ (Глубина: 1)
# 2025-12-14 14:49:36,596 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/raspisanievvi/ (Глубина: 1)
# 2025-12-14 14:49:37,208 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/formaprovedeniyavvi/ (Глубина: 1)
# 2025-12-14 14:49:37,745 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/programmavvi/ (Глубина: 1)
# 2025-12-14 14:49:38,327 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/results_vvi/ (Глубина: 1)
# 2025-12-14 14:49:38,937 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/srokipriemabyudzhet/ (Глубина: 1)
# 2025-12-14 14:49:39,894 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/srokipriemaplatka/ (Глубина: 1)
# 2025-12-14 14:49:40,481 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/targeted_training/ (Глубина: 1)
# 2025-12-14 14:49:41,056 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/podborpredpriyatiyazakazchika/ (Глубина: 1)
# 2025-12-14 14:49:41,594 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/tselevayakvota/ (Глубина: 1)
# 2025-12-14 14:49:42,232 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/stoimostobucheniya/ (Глубина: 1)
# 2025-12-14 14:49:42,809 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/stipendii/ (Глубина: 1)
# 2025-12-14 14:49:43,344 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/programmaloyalnosti/ (Глубина: 1)
# 2025-12-14 14:49:43,890 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/apriemgrazhdansovz/ (Глубина: 1)
# 2025-12-14 14:49:44,385 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/astat/ (Глубина: 1)
# 2025-12-14 14:49:44,997 - INFO - Обработка 4 таблиц на странице https://priem.stankin.ru/aspirantura/astat/...
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_13856\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_13856\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_13856\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_13856\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# 2025-12-14 14:49:45,088 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/ranked-lists/ (Глубина: 1)
# 2025-12-14 14:49:45,675 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/ranked-lists-ext/?order=1 (Глубина: 1)
# 2025-12-14 14:49:46,269 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/name-lists/ (Глубина: 1)
# 2025-12-14 14:49:46,831 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/bsprikazy/ (Глубина: 1)
# 2025-12-14 14:49:47,429 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/ofitsialnyedokumenty/ (Глубина: 1)
# 2025-12-14 14:49:47,984 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/zadatvoprospk/ (Глубина: 1)
# 2025-12-14 14:49:48,540 - INFO - -> Парсинг URL: https://priem.stankin.ru/priemnayakomissiyastankin_hqev/ (Глубина: 1)
# 2025-12-14 14:49:49,141 - INFO - -> Парсинг URL: https://priem.stankin.ru/perevod_v_Stankin/ (Глубина: 1)
# 2025-12-14 14:49:49,624 - INFO - -> Парсинг URL: https://priem.stankin.ru/youngschool (Глубина: 2)
# 2025-12-14 14:49:50,128 - INFO - -> Парсинг URL: https://priem.stankin.ru/olimpiady/MSO_nachertatlnaya_geometriya/ (Глубина: 2)
# 2025-12-14 14:49:50,595 - INFO - -> Парсинг URL: https://priem.stankin.ru/olimpiady/MSO_programmirovanie/ (Глубина: 2)
# 2025-12-14 14:49:51,045 - INFO - -> Парсинг URL: https://priem.stankin.ru/olimpiady/MSO_computernaya_grafika/ (Глубина: 2)
# 2025-12-14 14:49:51,540 - INFO - -> Парсинг URL: https://priem.stankin.ru/olimpiady/MSO_programnii_dizain/ (Глубина: 2)
# 2025-12-14 14:49:52,032 - INFO - -> Парсинг URL: https://priem.stankin.ru/olimpiady/MSO_teoreticheskya_mehanika/ (Глубина: 2)
# 2025-12-14 14:49:52,538 - INFO - -> Парсинг URL: https://priem.stankin.ru/olimpiady/MSO_matematika/ (Глубина: 2)
# 2025-12-14 14:49:53,038 - INFO - -> Парсинг URL: https://priem.stankin.ru/olimpiady/MSO_informatika/ (Глубина: 2)
# 2025-12-14 14:49:53,482 - INFO - -> Парсинг URL: https://priem.stankin.ru/olimpiady/MSO_fizika/ (Глубина: 2)
# 2025-12-14 14:49:54,012 - INFO - -> Парсинг URL: https://priem.stankin.ru/olimpiady/MSO_inostranniy_yazik/ (Глубина: 2)
# 2025-12-14 14:49:54,478 - INFO - -> Парсинг URL: https://priem.stankin.ru/olimpiady/MSO_teoriya_mehanizmov_i_mashin/ (Глубина: 2)
# 2025-12-14 14:49:54,981 - INFO - -> Парсинг URL: https://priem.stankin.ru/olimpiady/MSO_programmirovanie_obrabotki_na_stankah_s_CHPU_hgbb/ (Глубина: 2)
# 2025-12-14 14:49:55,467 - INFO - -> Парсинг URL: https://priem.stankin.ru/olimpiady/MSO_ekologiya_i_proizvodstvo/ (Глубина: 2)
# 2025-12-14 14:49:55,972 - INFO - -> Парсинг URL: https://priem.stankin.ru/olimpiady/MSO_upravlenie_vysokotekhnologichnym_predpriyatiem/ (Глубина: 2)
# 2025-12-14 14:49:56,491 - INFO - -> Парсинг URL: https://priem.stankin.ru/olimpiady/MSO_tekhnologii_mashinostroeniya/ (Глубина: 2)
# 2025-12-14 14:49:56,982 - INFO - -> Парсинг URL: https://priem.stankin.ru/olimpiady/MSO_proektirovanie_sredstv_proizvodstva/ (Глубина: 2)
# 2025-12-14 14:49:57,499 - INFO - -> Парсинг URL: https://priem.stankin.ru/olimpiady/MSO_soprotivlenie_materialov/ (Глубина: 2)
# 2025-12-14 14:49:58,020 - INFO - -> Парсинг URL: https://priem.stankin.ru/BS_Gosuslugi/ (Глубина: 2)
# 2025-12-14 14:49:58,562 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/01.03.04/ (Глубина: 2)
# 2025-12-14 14:49:59,199 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/09.03.01/ (Глубина: 2)
# 2025-12-14 14:49:59,852 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/09.03.02/ (Глубина: 2)
# 2025-12-14 14:50:00,507 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/09.03.03/ (Глубина: 2)
# 2025-12-14 14:50:01,147 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/09.03.04/ (Глубина: 2)
# 2025-12-14 14:50:01,800 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/12.03.01/ (Глубина: 2)
# 2025-12-14 14:50:02,411 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/15.03.01/ (Глубина: 2)
# 2025-12-14 14:50:03,060 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/15.03.01.01/ (Глубина: 2)
# 2025-12-14 14:50:03,746 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/15.03.02/ (Глубина: 2)
# 2025-12-14 14:50:04,404 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/15.03.04/ (Глубина: 2)
# 2025-12-14 14:50:05,074 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/15.03.05/ (Глубина: 2)
# 2025-12-14 14:50:05,742 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/15.03.06/ (Глубина: 2)
# 2025-12-14 14:50:06,404 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/15.05.01/ (Глубина: 2)
# 2025-12-14 14:50:07,053 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/20.03.01/ (Глубина: 2)
# 2025-12-14 14:50:07,687 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/22.03.01/ (Глубина: 2)
# 2025-12-14 14:50:08,348 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/27.03.01/ (Глубина: 2)
# 2025-12-14 14:50:08,964 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/27.03.02/ (Глубина: 2)
# 2025-12-14 14:50:09,615 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/27.03.04/ (Глубина: 2)
# 2025-12-14 14:50:10,654 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/38.03.01/ (Глубина: 2)
# 2025-12-14 14:50:11,305 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/38.03.02/ (Глубина: 2)
# 2025-12-14 14:50:11,948 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/38.03.03/ (Глубина: 2)
# 2025-12-14 14:50:12,604 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/info_perv_2025/ (Глубина: 2)
# 2025-12-14 14:50:13,183 - INFO - Обработка 4 таблиц на странице https://priem.stankin.ru/bakalavriatispetsialitet/info_perv_2025/...
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_13856\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_13856\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_13856\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# C:\Users\MainAdmUser\AppData\Local\Temp\ipykernel_13856\3488671794.py:24: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(str(table))[0]
# 2025-12-14 14:50:13,253 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/info_perv_2025_platnoe/ (Глубина: 2)
# 2025-12-14 14:50:13,834 - INFO - -> Парсинг URL: https://priem.stankin.ru/magistratura/napravleniya/09.04.01/ (Глубина: 2)
# 2025-12-14 14:50:14,480 - INFO - -> Парсинг URL: https://priem.stankin.ru/magistratura/napravleniya/09.04.04/ (Глубина: 2)
# 2025-12-14 14:50:15,115 - INFO - -> Парсинг URL: https://priem.stankin.ru/magistratura/napravleniya/12.04.01/ (Глубина: 2)
# 2025-12-14 14:50:15,747 - INFO - -> Парсинг URL: https://priem.stankin.ru/magistratura/napravleniya/15.04.02/ (Глубина: 2)
# 2025-12-14 14:50:16,385 - INFO - -> Парсинг URL: https://priem.stankin.ru/magistratura/napravleniya/15.04.04/ (Глубина: 2)
# 2025-12-14 14:50:17,031 - INFO - -> Парсинг URL: https://priem.stankin.ru/magistratura/napravleniya/15.04.05/ (Глубина: 2)
# 2025-12-14 14:50:17,662 - INFO - -> Парсинг URL: https://priem.stankin.ru/magistratura/napravleniya/15.04.05.01_siip/ (Глубина: 2)
# 2025-12-14 14:50:18,291 - INFO - -> Парсинг URL: https://priem.stankin.ru/magistratura/napravleniya/15.04.05.02_rpc/ (Глубина: 2)
# 2025-12-14 14:50:18,910 - INFO - -> Парсинг URL: https://priem.stankin.ru/magistratura/napravleniya/15.04.06/ (Глубина: 2)
# 2025-12-14 14:50:19,578 - INFO - -> Парсинг URL: https://priem.stankin.ru/magistratura/napravleniya/20.04.01/ (Глубина: 2)
# 2025-12-14 14:50:20,201 - INFO - -> Парсинг URL: https://priem.stankin.ru/magistratura/napravleniya/27.04.02/ (Глубина: 2)
# 2025-12-14 14:50:20,828 - INFO - -> Парсинг URL: https://priem.stankin.ru/magistratura/napravleniya/27.04.04/ (Глубина: 2)
# 2025-12-14 14:50:21,463 - INFO - -> Парсинг URL: https://priem.stankin.ru/magistratura/napravleniya/38.04.02/ (Глубина: 2)
# 2025-12-14 14:50:22,108 - INFO - -> Парсинг URL: https://priem.stankin.ru/magistratura/napravleniya/38.04.03/ (Глубина: 2)
# 2025-12-14 14:50:22,699 - INFO - -> Парсинг URL: https://priem.stankin.ru/magistratura/napravleniya/38.04.04/ (Глубина: 2)
# 2025-12-14 14:50:23,316 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/napravleniya/1.2.2 (Глубина: 2)
# 2025-12-14 14:50:23,959 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/napravleniya/2.2.11 (Глубина: 2)
# 2025-12-14 14:50:24,566 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/napravleniya/2.3.1 (Глубина: 2)
# 2025-12-14 14:50:25,174 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/napravleniya/2.3.3 (Глубина: 2)
# 2025-12-14 14:50:25,819 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/napravleniya/2.3.7 (Глубина: 2)
# 2025-12-14 14:50:26,423 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/napravleniya/2.5.1 (Глубина: 2)
# 2025-12-14 14:50:27,008 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/napravleniya/2.5.4 (Глубина: 2)
# 2025-12-14 14:50:27,590 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/napravleniya/2.5.5 (Глубина: 2)
# 2025-12-14 14:50:28,195 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/napravleniya/2.5.6 (Глубина: 2)
# 2025-12-14 14:50:28,840 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/napravleniya/2.5.7 (Глубина: 2)
# 2025-12-14 14:50:29,477 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/napravleniya/2.5.22 (Глубина: 2)
# 2025-12-14 14:50:30,111 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/napravleniya/5.2.3 (Глубина: 2)
# 2025-12-14 14:50:30,720 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/napravleniya/5.7.6 (Глубина: 2)
# 2025-12-14 14:50:31,342 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/napravleniya/1.2.2/ (Глубина: 2)
# 2025-12-14 14:50:31,931 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/napravleniya/2.2.11/ (Глубина: 2)
# 2025-12-14 14:50:32,528 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/napravleniya/2.3.1/ (Глубина: 2)
# 2025-12-14 14:50:33,146 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/napravleniya/2.3.3/ (Глубина: 2)
# 2025-12-14 14:50:33,755 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/napravleniya/2.3.7/ (Глубина: 2)
# 2025-12-14 14:50:34,287 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/napravleniya/2.5.1/ (Глубина: 2)
# 2025-12-14 14:50:34,919 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/napravleniya/2.5.4/ (Глубина: 2)
# 2025-12-14 14:50:35,481 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/napravleniya/2.5.5/ (Глубина: 2)
# 2025-12-14 14:50:36,049 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/napravleniya/2.5.6/ (Глубина: 2)
# 2025-12-14 14:50:37,065 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/napravleniya/2.5.7/ (Глубина: 2)
# 2025-12-14 14:50:37,711 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/napravleniya/2.5.22/ (Глубина: 2)
# 2025-12-14 14:50:38,348 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/napravleniya/5.2.3/ (Глубина: 2)
# 2025-12-14 14:50:38,982 - INFO - -> Парсинг URL: https://priem.stankin.ru/aspirantura/napravleniya/5.7.6/ (Глубина: 2)
# 2025-12-14 14:50:39,601 - INFO - -> Парсинг URL: https://priem.stankin.ru/priemnayakomissiyastankin_hqev/+7(499) 973-39-66 (Глубина: 2)
# 2025-12-14 14:50:39,962 - ERROR - Ошибка при загрузке https://priem.stankin.ru/priemnayakomissiyastankin_hqev/+7(499) 973-39-66: 404 Client Error: Not Found for url: https://priem.stankin.ru/priemnayakomissiyastankin_hqev/+7(499)%20973-39-66
# 2025-12-14 14:50:39,963 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/profilinapravleniy/MMMQTDA/ (Глубина: 3)
# 2025-12-14 14:50:40,314 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/profilinapravleniy/DSPDTE/ (Глубина: 3)
# 2025-12-14 14:50:40,796 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/profilinapravleniy/DMSISES/ (Глубина: 3)
# 2025-12-14 14:50:41,275 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/profilinapravleniy/MSMPS/ (Глубина: 3)
# 2025-12-14 14:50:41,772 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/profilinapravleniy/DM/ (Глубина: 3)
# 2025-12-14 14:50:42,264 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/profilinapravleniy/SASPD/ (Глубина: 3)
# 2025-12-14 14:50:42,759 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/profilinapravleniy/im_et/ (Глубина: 3)
# 2025-12-14 14:50:43,295 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/profilinapravleniy/MTMbP/ (Глубина: 3)
# 2025-12-14 14:50:43,808 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/profilinapravleniy/MMC/ (Глубина: 3)
# 2025-12-14 14:50:44,298 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/profilinapravleniy/ccm/ (Глубина: 3)
# 2025-12-14 14:50:44,844 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/profilinapravleniy/HMHDH/ (Глубина: 3)
# 2025-12-14 14:50:45,286 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/profilinapravleniy/ATPP/ (Глубина: 3)
# 2025-12-14 14:50:45,776 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/profilinapravleniy/TPMBI/ (Глубина: 3)
# 2025-12-14 14:50:46,151 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/profilinapravleniy/DTSHEMPT/ (Глубина: 3)
# 2025-12-14 14:50:46,644 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/profilinapravleniy/rrs_da/ (Глубина: 3)
# 2025-12-14 14:50:47,142 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/profilinapravleniy/DTCME/ (Глубина: 3)
# 2025-12-14 14:50:47,658 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/profilinapravleniy/IDOS/ (Глубина: 3)
# 2025-12-14 14:50:48,126 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/profilinapravleniy/MCTNM/ (Глубина: 3)
# 2025-12-14 14:50:48,615 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/profilinapravleniy/edp/ (Глубина: 3)
# 2025-12-14 14:50:49,125 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/profilinapravleniy/ohtb/ (Глубина: 3)
# 2025-12-14 14:50:49,632 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/profilinapravleniy/hpm/ (Глубина: 3)
# 2025-12-14 14:50:50,155 - INFO - -> Парсинг URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/profilinapravleniy/pmht/ (Глубина: 3)
# 2025-12-14 14:50:50,648 - INFO - -> Парсинг URL: https://priem.stankin.ru/magistratura/napravleniya/profilinapravleniy/pmie_ee_sppm/ (Глубина: 3)
# 2025-12-14 14:50:51,142 - INFO - -> Парсинг URL: https://priem.stankin.ru/magistratura/napravleniya/profilinapravleniy/pmie_ee_ida/ (Глубина: 3)
# ...
# 2025-12-14 14:50:59,413 - INFO - URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/profilinapravleniy/ohtb/ -> Исходный текст разбит на 5 чанков.
# 2025-12-14 14:50:59,414 - INFO - URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/profilinapravleniy/hpm/ -> Исходный текст разбит на 5 чанков.
# 2025-12-14 14:50:59,416 - INFO - URL: https://priem.stankin.ru/bakalavriatispetsialitet/nap/profilinapravleniy/pmht/ -> Исходный текст разбит на 6 чанков.
# 2025-12-14 14:50:59,417 - INFO - URL: https://priem.stankin.ru/magistratura/napravleniya/profilinapravleniy/pmie_ee_sppm/ -> Исходный текст разбит на 5 чанков.
# 2025-12-14 14:50:59,418 - INFO - URL: https://priem.stankin.ru/magistratura/napravleniya/profilinapravleniy/pmie_ee_ida/ -> Исходный текст разбит на 6 чанков.
# 2025-12-14 14:50:59,420 - INFO - URL: https://priem.stankin.ru/magistratura/napravleniya/profilinapravleniy/pmie_ee_imdesm/ -> Исходный текст разбит на 5 чанков.
# 2025-12-14 14:50:59,421 - INFO - URL: https://priem.stankin.ru/magistratura/napravleniya/profilinapravleniy/pmie_ee_cmcts/ -> Исходный текст разбит на 5 чанков.
# 2025-12-14 14:50:59,422 - INFO - URL: https://priem.stankin.ru/magistratura/napravleniya/profilinapravleniy/pmie_ee_aibd/ -> Исходный текст разбит на 5 чанков.
# 2025-12-14 14:50:59,424 - INFO - URL: https://priem.stankin.ru/magistratura/napravleniya/profilinapravleniy/pmie_ee_egcg/ -> Исходный текст разбит на 5 чанков.
# 2025-12-14 14:50:59,425 - INFO - URL: https://priem.stankin.ru/konsultatsiya/ -> Исходный текст разбит на 2 чанков.
# 2025-12-14 14:50:59,426 - INFO - URL: https://priem.stankin.ru/magistratura/napravleniya/profilinapravleniy/TPISPC/ -> Исходный текст разбит на 6 чанков.
# 2025-12-14 14:50:59,428 - INFO - URL: https://priem.stankin.ru/magistratura/napravleniya/profilinapravleniy/MIT/ -> Исходный текст разбит на 12 чанков.
# 2025-12-14 14:50:59,430 - INFO - URL: https://priem.stankin.ru/magistratura/napravleniya/profilinapravleniy/SETP/ -> Исходный текст разбит на 6 чанков.
# 2025-12-14 14:50:59,431 - INFO - URL: https://priem.stankin.ru/magistratura/napravleniya/profilinapravleniy/RPC/ -> Исходный текст разбит на 6 чанков.
# 2025-12-14 14:50:59,432 - INFO - URL: https://priem.stankin.ru/magistratura/napravleniya/profilinapravleniy/pmie_ee/ -> Исходный текст разбит на 5 чанков.
# 2025-12-14 14:50:59,433 - INFO - URL: https://priem.stankin.ru/magistratura/napravleniya/profilinapravleniy/hbm/ -> Исходный текст разбит на 5 чанков.
# 2025-12-14 14:50:59,434 - INFO - URL: https://priem.stankin.ru/magistratura/napravleniya/profilinapravleniy/edp_pbye/ -> Исходный текст разбит на 5 чанков.
# 2025-12-14 14:50:59,435 - INFO - URL: https://priem.stankin.ru/magistratura/napravleniya/profilinapravleniy/prm/ -> Исходный текст разбит на 4 чанков.
# 2025-12-14 14:50:59,436 - INFO - URL: https://priem.stankin.ru/magistratura/napravleniya/profilinapravleniy/pmie/ -> Исходный текст разбит на 4 чанков.
# 2025-12-14 14:50:59,437 - INFO - URL: https://priem.stankin.ru/magistratura/napravleniya/profilinapravleniy/pmie_srppie/ -> Исходный текст разбит на 5 чанков.
# 2025-12-14 14:50:59,437 - INFO - SUCCESS: Итоговое количество чанков, готовых к индексированию: 707
# 2025-12-14 14:50:59,438 - INFO - Инициализация ChromaDB по пути: ./stankin_db
# 2025-12-14 14:50:59,461 - INFO - Anonymized telemetry enabled. See                     https://docs.trychroma.com/telemetry for more information.
# 2025-12-14 14:50:59,657 - INFO - Коллекция 'stankin_collection' не найдена или не требует удаления.
# 2025-12-14 14:50:59,685 - INFO - Коллекция 'stankin_collection' готова к заполнению.
# Batches:   0%|          | 0/16 [00:00<?, ?it/s]
# 2025-12-14 14:51:16,188 - INFO - Индексирован пакет: 0 - 500
# Batches:   0%|          | 0/7 [00:00<?, ?it/s]
# 2025-12-14 14:51:18,989 - INFO - Индексирован пакет: 500 - 707
# 2025-12-14 14:51:19,047 - CRITICAL - SUCCESS: Индексирование завершено. Всего чанков в БД: 707
# 2025-12-14 14:51:19,048 - INFO - --------------------------------------------------
# 2025-12-14 14:51:19,048 - INFO - НАЧАЛО ТЕСТИРОВАНИЯ КАЧЕСТВА RAG
# 2025-12-14 14:51:19,049 - INFO - Тестовый запрос: 'Какие документы нужны для подачи заявления в МГТУ СТАНКИН?'
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# 2025-12-14 14:51:19,122 - CRITICAL -
# --- 5 САМЫХ РЕЛЕВАНТНЫХ ЧАНКОВ (RAG-РЕЗУЛЬТАТ) ---
#
# 2025-12-14 14:51:19,123 - INFO - --------------------------------------------------
# 2025-12-14 14:51:19,124 - INFO - --------------------------------------------------
# 2025-12-14 14:51:19,124 - INFO - НАЧАЛО ТЕСТИРОВАНИЯ КАЧЕСТВА RAG
# 2025-12-14 14:51:19,125 - INFO - Тестовый запрос: 'Сколько баллов нужно набрать, для того чтобы поступить на направление 09.03.03?'
# [1] Дистанция: 0.3404
#     Источник: https://priem.stankin.ru/bakalavriatispetsialitet/submit_documents_bs/
#     Содержание: гражданство Ксерокопия документа установленного образца об образовании Ксерокопия СНИЛС Если есть: ксерокопии документов, подтверждающие наличие особых прав, индивидуальные достижения, победы в олимпиадах или другие документы, влияющие на порядок поступления Почтовый адрес: 127994, ГСП-4, г. Москва,...
#
# [2] Дистанция: 0.3464
#     Источник: https://priem.stankin.ru/bakalavriatispetsialitet/info_perv_2025/
#     Содержание: на обработку персональных данных, разрешенных субъектом персональных данных для распространения (бланк)) ; Пример заполненного "Согласие на обработку персональных данных, разрешенных субъектом персональных данных для распространения". важно!!! 1. Если у Вас отсутствуют заранее заполненные согласия о...
#
# [3] Дистанция: 0.3524
#     Источник: https://priem.stankin.ru/bakalavriatispetsialitet/info_perv_2025_platnoe/
#     Содержание: Согласие на обработку персональных данных, разрешенных субъектом персональных данных для распространения (бланк)) ; Пример заполненного "Согласие на обработку персональных данных, разрешенных субъектом персональных данных для распространения". важно!!! 1. Если у Вас отсутствуют заранее заполненные с...
#
# [4] Дистанция: 0.3608
#     Источник: https://priem.stankin.ru/BS_Gosuslugi/
#     Содержание: БС Госуслуги ☰ Подача документов в университет через Госуслуги Преимущества электронной подачи Экономия времени Подача документов занимает не более 15 минут без необходимости посещать приемную комиссию Минимум документов Большинство документов автоматически загружаются из вашего профиля на Госуслуга...
#
# [5] Дистанция: 0.3633
#     Источник: https://priem.stankin.ru/bakalavriatispetsialitet/info_perv_2025/
#     Содержание: Пример заполненного "Согласие родителя или законного представителя на обработку персональных данных несовершеннолетнего"; Согласие на обработку персональных данных, разрешенных субъектом персональных данных для распространения (бланк)) ; Пример заполненного "Согласие на обработку персональных данных...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# 2025-12-14 14:51:19,166 - CRITICAL -
# --- 5 САМЫХ РЕЛЕВАНТНЫХ ЧАНКОВ (RAG-РЕЗУЛЬТАТ) ---
#
# 2025-12-14 14:51:19,167 - INFO - --------------------------------------------------
# 2025-12-14 14:51:19,168 - INFO - --------------------------------------------------
# 2025-12-14 14:51:19,168 - INFO - НАЧАЛО ТЕСТИРОВАНИЯ КАЧЕСТВА RAG
# 2025-12-14 14:51:19,168 - INFO - Тестовый запрос: 'Сколько баллов дают за индивидуальные достижения?'
# [1] Дистанция: 0.4054
#     Источник: https://priem.stankin.ru/aspirantura/srokipriemaplatka/
#     Содержание: abitur@stankin.ru График работы: пн – чт с 10:00 до 18:00, пт - с 10:00 до 16:45 Остались вопросы? Записаться на консультацию...
#
# [2] Дистанция: 0.4088
#     Источник: https://priem.stankin.ru/magistratura/formaprovedeniyaekzamenov/
#     Содержание: с полученной оценкой результатов вступительного испытания. Максимальное количество баллов для каждого вступительного испытания по программам магистратуры устанавливается равным 100 баллам. Минимальное количество баллов для каждого вступительного испытания по программам магистратуры устанавливается р...
#
# [3] Дистанция: 0.4101
#     Источник: https://priem.stankin.ru/bakalavriatispetsialitet/training_programs/
#     Содержание: График работы: пн – чт с 10:00 до 18:00, пт - с 10:00 до 16:45 Остались вопросы? Записаться на консультацию...
#
# [4] Дистанция: 0.4101
#     Источник: https://priem.stankin.ru/bakalavriatispetsialitet/prikazy/
#     Содержание: График работы: пн – чт с 10:00 до 18:00, пт - с 10:00 до 16:45 Остались вопросы? Записаться на консультацию...
#
# [5] Дистанция: 0.4101
#     Источник: https://priem.stankin.ru/magistratura/datypriemaplatka/
#     Содержание: График работы: пн – чт с 10:00 до 18:00, пт - с 10:00 до 16:45 Остались вопросы? Записаться на консультацию...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# 2025-12-14 14:51:19,209 - CRITICAL -
# --- 5 САМЫХ РЕЛЕВАНТНЫХ ЧАНКОВ (RAG-РЕЗУЛЬТАТ) ---
#
# 2025-12-14 14:51:19,210 - INFO - --------------------------------------------------
# 2025-12-14 14:51:19,210 - INFO - --------------------------------------------------
# 2025-12-14 14:51:19,211 - INFO - НАЧАЛО ТЕСТИРОВАНИЯ КАЧЕСТВА RAG
# 2025-12-14 14:51:19,212 - INFO - Тестовый запрос: 'Какие направления подготовки бакалавриата есть в Станкине?'
# [1] Дистанция: 0.4098
#     Источник: https://priem.stankin.ru/bakalavriatispetsialitet/Individual_achievements/
#     Содержание: БС Индивидуальные достижения ☰ индивидуальные достижения Сумма баллов, начисленных поступающему за индивидуальные достижения, не может быть более 10 баллов. аттестат/диплом с отличием Наличие аттестата с отличием, диплома с отличием, золотая(серебряная медаль) 10 баллов Олимпиады Участие и (или) рез...
#
# [2] Дистанция: 0.4416
#     Источник: https://priem.stankin.ru/magistratura/formaprovedeniyaekzamenov/
#     Содержание: с полученной оценкой результатов вступительного испытания. Максимальное количество баллов для каждого вступительного испытания по программам магистратуры устанавливается равным 100 баллам. Минимальное количество баллов для каждого вступительного испытания по программам магистратуры устанавливается р...
#
# [3] Дистанция: 0.4423
#     Источник: https://priem.stankin.ru/aspirantura/id/
#     Содержание: А Индивидуальные достижения ☰ индивидуальные достижения Сумма баллов, начисленных поступающему за индивидуальные достижения, не может быть более 30 баллов. диплом С отличием Наличие диплома об образовании с отличием, представленного поступающим при подаче документов 15 баллов победа в конкурсах всер...
#
# [4] Дистанция: 0.4437
#     Источник: https://priem.stankin.ru/magistratura/id/
#     Содержание: М Индивидуальные достижения ☰ индивидуальные достижения Сумма баллов, начисленных поступающему за индивидуальные достижения, не может быть более 30 баллов. диплом С отличием Наличие диплома об образовании с отличием, представленного поступающим при подаче документов. 15 баллов победа в конкурсах все...
#
# [5] Дистанция: 0.4737
#     Источник: https://priem.stankin.ru/aspirantura/formaprovedeniyavvi/
#     Содержание: испытаний по программам подготовки научных и научно-педагогических кадров в аспирантуре в 2025/2026 учебном году Максимальное количество баллов для каждого вступительного испытания по программы подготовки научных и научно-педагогических кадров в аспирантуре устанавливается равным 100 баллам. Минимал...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# 2025-12-14 14:51:19,254 - CRITICAL -
# --- 5 САМЫХ РЕЛЕВАНТНЫХ ЧАНКОВ (RAG-РЕЗУЛЬТАТ) ---
#
# 2025-12-14 14:51:19,255 - INFO - --------------------------------------------------
# 2025-12-14 14:51:19,256 - INFO - --------------------------------------------------
# 2025-12-14 14:51:19,256 - INFO - НАЧАЛО ТЕСТИРОВАНИЯ КАЧЕСТВА RAG
# 2025-12-14 14:51:19,257 - INFO - Тестовый запрос: 'Когда начинаются вступительные испытания в магистратуре?'
# [1] Дистанция: 0.3516
#     Источник: https://priem.stankin.ru/aspirantura/formaprovedeniyavvi/
#     Содержание: испытаний по программам подготовки научных и научно-педагогических кадров в аспирантуре в 2025/2026 учебном году Максимальное количество баллов для каждого вступительного испытания по программы подготовки научных и научно-педагогических кадров в аспирантуре устанавливается равным 100 баллам. Минимал...
#
# [2] Дистанция: 0.3662
#     Источник: https://priem.stankin.ru/aspirantura/raspisanievvi/
#     Содержание: А Расписание ВВИ ☰ расписание вступительных экзаменов для поступающих на 1 курс по программам подготовки Аспирантуры В рамках платной основы экзамен по всем направлениям будет проходить 05.09.2025 в 10:00. Напоминаем, что экзамены проходят дистанционно По организационным вопросам обращайтесь в приём...
#
# [3] Дистанция: 0.3742
#     Источник: https://priem.stankin.ru/bakalavriatispetsialitet/nap/15.05.01/
#     Содержание: вузов. Инженерные профессии занимают более 12% всех вакансий в профобласти "производство" на hh.ru. ПРОХОДНОЙ БАЛЛ проходной балл – балл абитуриента, который находился в приказе о зачислении на последней строчке. 214 проходной балл в 2025 г. 195 проходной балл в 2024 г. 138 проходной балл в 2023 г. ...
#
# [4] Дистанция: 0.3779
#     Источник: https://priem.stankin.ru/magistratura/raspisanievvi/
#     Содержание: М Расписание ВВИ ☰ расписание консультаций И ЭКЗАМЕНОВ для поступающих на 1 курс по программам подготовки магистратуры В рамках платной основы экзамен по всем направлениям будет проходить 05.09.2025 в 10:00. Напоминаем, что экзамены проходят дистанционно По организационным вопросам обращайтесь в при...
#
# [5] Дистанция: 0.3807
#     Источник: https://priem.stankin.ru/bakalavriatispetsialitet/nap/20.03.01/
#     Содержание: 20.03.01 Техносферная безопасность ☰ 20.03.01 Техносферная безопасность Подать документы О программе Характерной особенностью подготовки бакалавров по направлению «Техносферная безопасность», является ее направленность на совершенствование современного, конкурентоспособного машиностроительного произ...
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# 2025-12-14 14:51:19,298 - CRITICAL -
# --- 5 САМЫХ РЕЛЕВАНТНЫХ ЧАНКОВ (RAG-РЕЗУЛЬТАТ) ---
#
# 2025-12-14 14:51:19,299 - INFO - --------------------------------------------------
# [1] Дистанция: 0.4063
#     Источник: https://priem.stankin.ru/bakalavriatispetsialitet/formaprovedeniyaekzamenov/
#     Содержание: причины признаются как не сдавшие вступительное испытание. После объявления результатов письменного вступительного испытания поступающий имеет право ознакомиться с результатами проверки и оценивания его работы. Лица, не прошедшие вступительное испытание по уважительной причине, допускаются к сдаче в...
#
# [2] Дистанция: 0.4119
#     Источник: https://priem.stankin.ru/aspirantura/formaprovedeniyavvi/
#     Содержание: А форма проведения ВВИ ☰ форма проведения экзаменов Вступительные испытания сдаются: на русском языке в очном формате (возможен дистанционный формат по согласованию) однократно Результаты вступительного испытания объявляются на официальном сайте Приёмной комиссии МГТУ "СТАНКИН". Лица, нарушившие пра...
#
# [3] Дистанция: 0.4301
#     Источник: https://priem.stankin.ru/magistratura/formaprovedeniyaekzamenov/
#     Содержание: с полученной оценкой результатов вступительного испытания. Максимальное количество баллов для каждого вступительного испытания по программам магистратуры устанавливается равным 100 баллам. Минимальное количество баллов для каждого вступительного испытания по программам магистратуры устанавливается р...
#
# [4] Дистанция: 0.4343
#     Источник: https://priem.stankin.ru/magistratura/formaprovedeniyaekzamenov/
#     Содержание: М Форма проведения экзаменов ☰ форма проведения экзаменов Указанная здесь информация представлена в сжатом и понятном формате. С полной информацией можно ознакомится здесь . Вступительные испытания сдаются: на русском языке в соответствии с программой вступительных испытаний в дистанционном формате ...
#
# [5] Дистанция: 0.4380
#     Источник: https://priem.stankin.ru/aspirantura/srokipriemaplatka/
#     Содержание: А Сроки приема на платные места ☰ Сроки приема на платные места обучения по программам аспирантуры 20 июня, 2025 Начало приема документов 11 августа, 2025 Начало внутренних вступительных испытаний 23 августа, 2025 День публикации конкурсных списков 2 сентября, 2025 Завершение приема документов от по...
